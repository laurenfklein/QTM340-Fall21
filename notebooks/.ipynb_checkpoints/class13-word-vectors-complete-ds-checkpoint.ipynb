# %% [markdown]
# # Word Embedding Models: word2vec #
#
# *Lauren F. Klein wrote version 1.0 of this notebook based on the [Advanced Topics in Word Vectors workshop](https://dh2018.adho.org/en/machine-reading-part-ii-advanced-topics-in-word-vectors/) at DH 2018 as well as tutorials by [Radim Rehurek](https://rare-technologies.com/word2vec-tutorial/) and [Chris McCormick](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/)**

# %% [markdown]
# ## Why word2vec?

# %% [markdown]
# At the beginning of this unit, we were introduced to the idea of turning texts into numbers through word vectors. In 2013, Tomas Mikolov and his team at Google used that idea to create word2vec, a word embedding model that is powerful for analyzing text. It is one method for predicting what word is likely to come next in a text; it also allows the exploration of similarity and analogy between words in a corpus.
#
# We'll be using gensim, a Python library, to use word2vec today.

# %% [markdown]
# ## Install gensim

# %%
# gensim is already installed on JupyterHub
#!pip install --upgrade gensim

# %% [markdown]
# ## Import gensim, nltk tokenizers, glob, and Path

# %%
import gensim # remember this! 
from nltk.tokenize import sent_tokenize
from nltk.tokenize.treebank import TreebankWordTokenizer
import nltk
nltk.download('punkt')
import glob
from pathlib import Path
# Out:
# [nltk_data] Downloading package punkt to /Users/dsinyki/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Read in our corpus

# %%
# next, we need to create our corpus.
# we will continue to use the NYT obituaries corpus

import os

base_dir = "../docs/NYT-Obituaries/" 

all_docs = [] # our list which will store the text of each doc; empty for now

docs = os.listdir(base_dir) # get a list of all the files in the directory

for doc in docs: # iterate through the docs
    if not doc.startswith('.'): # get only the .txt files
        with open(base_dir + doc, "r", encoding="utf-8") as file: # force unicode conversion to keep PCs happy
            text = file.read() # read in the file as a single text string
            all_docs.append(text) # append it to the all_docs list

# lastly, just check the length of all_docs to see if it's 147
len(all_docs)
# Out:
# 378

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# gensim takes text at the level of `sentences` as its input.
#
# So let's define a function that a takes a list of texts (e.g. our all_docs list) and converts it into sentences for gensim word2vec to use. The function will lower-case text and tokenize by sentence and word.

# %%
# need our handy nltk tokenizer 
tokenizer = TreebankWordTokenizer()

# and we'll get titles
directory = "../docs/NYT-Obituaries/"
files = glob.glob(f"{directory}/*.txt")
obit_titles = [Path(file).stem for file in files]

# and the function
def make_sentences(list_txt):
    all_txt = []
    counter = 0
    for txt in list_txt:
        lower_txt = txt.lower()
        sentences = sent_tokenize(lower_txt)
        sentences = [tokenizer.tokenize(sent) for sent in sentences]
        all_txt += sentences
        print(obit_titles[counter]) # let's print the title of the obit
        print(len(sentences))  # let's check how many sentences there are per obit
        print("\n")
        counter += 1
    return all_txt

# %%
# now let's run it
sentences = make_sentences(all_docs)
# Out:
# 1945-Adolf-Hitler
# 597
#
#
# 1915-F-W-Taylor
# 15
#
#
# 1975-Chiang-Kai-shek
# 240
#
#
# 1984-Ethel-Merman
# 110
#
#
# 1953-Jim-Thorpe
# 79
#
#
# 1964-Nella-Larsen
# 44
#
#
# 1955-Margaret-Abbott
# 52
#
#
# 1984-Lillian-Hellman
# 159
#
#
# 1959-Cecil-De-Mille
# 65
#
#
# 1928-Mabel-Craty
# 14
#
#
# 1973-Eddie-Rickenbacker
# 125
#
#
# 1989-Ferdinand-Marcos
# 53
#
#
# 1991-Martha-Graham
# 118
#
#
# 1997-Deng-Xiaoping
# 274
#
#
# 1938-George-E-Hale
# 31
#
#
# 1885-Ulysses-Grant
# 1619
#
#
# 1909-Sarah-Orne-Jewett
# 20
#
#
# 1957-Christian-Dior
# 43
#
#
# 1987-Clare-Boothe-Luce
# 94
#
#
# 1976-Jacques-Monod
# 41
#
#
# 1954-Getulio-Vargas
# 56
#
#
# 1979-Stan-Kenton
# 58
#
#
# 1990-Leonard-Bernstein
# 203
#
#
# 1972-Jackie-Robinson
# 164
#
#
# 1998-Fred-W-Friendly
# 81
#
#
# 1991-Leo-Durocher
# 44
#
#
# 1915-B-T-Washington
# 54
#
#
# 1997-James-Stewart
# 101
#
#
# 1981-Joe-Louis
# 156
#
#
# 1983-Muddy-Waters
# 38
#
#
# 1942-George-M-Cohan
# 160
#
#
# 1989-Samuel-Beckett
# 160
#
#
# 1962-Marilyn-Monroe
# 84
#
#
# 2000-Charles-M-Schulz
# 296
#
#
# 1967-Gregory-Pincus
# 59
#
#
# 1894-R-L-Stevenson
# 106
#
#
# 1978-Bruce-Catton
# 8
#
#
# 1982-Arthur-Rubinstein
# 174
#
#
# 1875-Andrew-Johnson
# 103
#
#
# 1974-Charles-Lindbergh
# 271
#
#
# 1964-Rachel-Carson
# 117
#
#
# 1953-Marjorie-Rawlings
# 34
#
#
# 1973-Otto-Klemperer
# 96
#
#
# 1963-Sylvia-Plath
# 53
#
#
# 1956-Charles-Merrill
# 63
#
#
# 1966-Lenny-Bruce
# 41
#
#
# 1908-Cleveland
# 133
#
#
# 1982-Anna-Freud
# 70
#
#
# 1941-Frank-Conrad
# 27
#
#
# 1966-Alfred-P-Sloan-Jr
# 155
#
#
# 1960-Beno-Gutenberg
# 8
#
#
# 1976-J-Paul-Getty
# 174
#
#
# 1891-P-T-Barnum
# 268
#
#
# 1901-Queen-Victoria
# 629
#
#
# 1970-Erich-Maria-Remarque
# 106
#
#
# 1989-August-A-Busch-Jr
# 41
#
#
# 1992-John-Cage
# 113
#
#
# 1994-Erik-Erikson
# 115
#
#
# 1990-Erte
# 45
#
#
# 1966-Chester-Nimitz
# 90
#
#
# 1954-Enrico-Fermi
# 54
#
#
# 1961-Primitive-Artist
# 80
#
#
# 1945-Bela-Bartok
# 43
#
#
# 1978-Pope-Paul-VI
# 46
#
#
# 1965-Martin-Buber
# 121
#
#
# 1971-Diane-Arbus
# 42
#
#
# 1973-Lyndon-Johnson
# 61
#
#
# 1998-Bob-Kane
# 71
#
#
# 1969-Judy-Garland
# 133
#
#
# 1959-Frank-Lloyd-Wright
# 113
#
#
# 1995-Ginger-Rogers
# 80
#
#
# 1920-Marlene-Dietrich
# 101
#
#
# 1998-Alan-B-Shepard-Jr
# 126
#
#
# 1971-Khrushchev
# 275
#
#
# 1935-Justice-Holmes
# 114
#
#
# 1969-David-Eisenhower
# 154
#
#
# 1992-Marsha-P-Johnson
# 61
#
#
# 1914-Alfred-Thayer-Mahan
# 64
#
#
# 1965-Branch-Rickey
# 104
#
#
# 1965-Albert-Schweitzer
# 197
#
#
# 1992-Isaac-Asimov
# 85
#
#
# 1989-William-B-Shockley
# 33
#
#
# 1910-William-James
# 38
#
#
# 1951-Fanny-Brice
# 37
#
#
# 1916-Jack-London
# 38
#
#
# 1947-Al-Capone
# 87
#
#
# 1989-Lucille-Ball
# 83
#
#
# 1980-Jean-Paul-Sartre
# 92
#
#
# 1969-Sonja-Henie
# 40
#
#
# 1976-Adolph-Zukor
# 87
#
#
# 1959-John-Dulles
# 193
#
#
# 1980-Alfred-Hitchcock
# 81
#
#
# 1901-Benjamin-Harrison
# 63
#
#
# 1994-Richard-Nixon
# 326
#
#
# 1917-Hilaire-G-E-Degas
# 9
#
#
# 1987-James-Baldwin
# 81
#
#
# 1941-Virginia-Woolf
# 40
#
#
# 1922-Alexander-Graham-Bell
# 94
#
#
# 1907-Qiu-Jin
# 54
#
#
# 1895-Fred-Douglass
# 133
#
#
# 1971-Florence-Blanchfield
# 19
#
#
# 1984-Ray-A-Kroc
# 67
#
#
# 1947-Fiorello-La-Guardia
# 215
#
#
# 1988-Louis-L-Amour
# 45
#
#
# 1902-Elizabeth-Cady-Stanton
# 73
#
#
# 1965-Shirley-Jackson
# 64
#
#
# 1979-John-Wayne
# 102
#
#
# 1994-Thomas-P-O-Neill-Jr
# 129
#
#
# 1982-Thelonious-Monk
# 61
#
#
# 1919-C-J-Walker
# 15
#
#
# 1954-Liberty-H-Bailey
# 25
#
#
# 1977-Dash-Ended
# 155
#
#
# 1936-Maxim-Gorky
# 97
#
#
# 2000-Pierre-Trudeau
# 145
#
#
# 1976-Mao-Tse-Tung
# 486
#
#
# 1955-Walter-White
# 37
#
#
# 1930-Conan-Doyle
# 95
#
#
# 1995-Jonas-Salk
# 96
#
#
# 1949-Mitchell
# 79
#
#
# 1951-Henrietta-Lacks
# 51
#
#
# 1903-James-M-N-Whistler
# 42
#
#
# 1950-A-J-Dempster
# 12
#
#
# 1937-Edith-Wharton
# 85
#
#
# 1935-Jane-Addams
# 117
#
#
# 1941-James-Joyce
# 68
#
#
# 1952-John-Dewey
# 139
#
#
# 1940-Marcus-Garvey
# 33
#
#
# 1971-Louis-Armstrong
# 179
#
#
# 1923-Warren-Harding
# 258
#
#
# 1937-John-Rockefeller
# 299
#
#
# 2000-Elliot-Richardson
# 55
#
#
# 1972-J-Edgar-Hoover
# 229
#
#
# 1975-Franco
# 190
#
#
# 1973-Jeanette-Rankin
# 44
#
#
# 1888-Louisa-M-Alcott
# 46
#
#
# 1977-Charles-Chaplin
# 251
#
#
# 1990-Ralph-David-Abernathy
# 67
#
#
# 1946-Lord-Keynes
# 60
#
#
# 1996-Gene-Kelly
# 103
#
#
# 1973-Roberto-Clemente
# 34
#
#
# 1986-Georgia-O-Keeffe
# 86
#
#
# 1990-Rex-Harrison
# 64
#
#
# 1916-Martian-Theory
# 36
#
#
# 1961-Ernest-Hemingway
# 113
#
#
# 1978-Margaret-Mead
# 118
#
#
# 1982-Ingrid-Bergman
# 103
#
#
# 1946-C-E-M-Clung
# 20
#
#
# 1977-Maria-Callas
# 166
#
#
# 1952-Eva-Peron
# 52
#
#
# 1961-Emily-Balch
# 31
#
#
# 1979-Arthur-Fiedler
# 71
#
#
# 1896-Harriet-Beecher-Stowe
# 123
#
#
# 1989-Andrei-Sakharov
# 175
#
#
# 1939-W-B-Yeats
# 63
#
#
# 1961-Hammarskjold
# 111
#
#
# 1969-Madhubala
# 59
#
#
# 1970-Edouard-Daladier
# 52
#
#
# 1988-John-Houseman
# 90
#
#
# 1992-William-Shawn
# 110
#
#
# 1950-Edna-St-V-Millay
# 51
#
#
# 1989-Claude-Pepper
# 63
#
#
# 1929-Marie-Curie
# 142
#
#
# 1972-The-Duke-of-Windsor
# 59
#
#
# 1984-Count-Basie
# 98
#
#
# 1998-Helen-Moody
# 47
#
#
# 1936-Anne-Macy
# 64
#
#
# 1900-Nietzsche
# 15
#
#
# 1880-Lucretia-Mott
# 13
#
#
# 1967-J-Robert-Oppenheimer
# 203
#
#
# 1984-Richard-Burton
# 101
#
#
# 1964-Sean-O-Casey
# 94
#
#
# 1931-Thomas-Edison
# 61
#
#
# 1971-Bobby-Jones
# 138
#
#
# 1914-John-P-Holland
# 10
#
#
# 1995-George-Abbott
# 111
#
#
# 1950-Henry-L-Stimson
# 104
#
#
# 1955-Dale-Carnegie
# 35
#
#
# 1934-T-A-Watson
# 28
#
#
# 1968-Martin-Luther-King-Jr
# 187
#
#
# 1933-Louis-C-Tiffany
# 36
#
#
# 1909-Geronimo
# 42
#
#
# 1952-Charles-Spaulding
# 15
#
#
# 1922-Nellie-Bly
# 12
#
#
# 1955-Cy-Young
# 28
#
#
# 1993-Arthur-Ashe
# 98
#
#
# 1986-Bernard-Malamud
# 79
#
#
# 1939-Howard-Carter
# 43
#
#
# 1994-Linus-C-Pauling
# 127
#
#
# 1967-Langston-Hughes
# 25
#
#
# 1948-Mohandas-K-Gandhi
# 187
#
#
# 1931-Melvil-Dewey
# 35
#
#
# 1969-Everett-Dirksen
# 180
#
#
# 1968-Helen-Keller
# 176
#
#
# 1992-Alex-Haley
# 38
#
#
# 1953-Eugene-O-Neill
# 99
#
#
# 1981-Anwar-el-Sadat
# 219
#
#
# 1937-Maurice-Ravel
# 42
#
#
# 1966-Margaret-Sanger
# 102
#
#
# 1989-I-F-Stone
# 58
#
#
# 1943-J-H-Kellogg
# 16
#
#
# 1985-Roger-Maris
# 53
#
#
# 1972-Mahalia-Jackson
# 87
#
#
# 1990-Greta-Garbo
# 131
#
#
# 1998-Benjamin-Spock
# 161
#
#
# 1994-Jessica-Tandy
# 152
#
#
# 1979-Richard-Rodgers
# 145
#
#
# 1958-W-C-Handy
# 48
#
#
# 1974-Ed-Sullivan
# 63
#
#
# 1989-Hirohito
# 60
#
#
# 1933-Calvin-Coolidge
# 254
#
#
# 1969-Ho-Chi-Minh
# 191
#
#
# 1987-John-Huston
# 87
#
#
# 1984-Johnny-Weissmuller
# 38
#
#
# 1969-Maureen-Connolly
# 35
#
#
# 1968-Yuri-Gagarin
# 43
#
#
# 1991-Peggy-Ashcroft
# 48
#
#
# 1979-A-Philip-Randolph
# 131
#
#
# 1946-Gertrude-Stein
# 62
#
#
# 1993-Thurgood-Marshall
# 148
#
#
# 1887-Emma-Lazarus
# 31
#
#
# 1986-James-Cagney
# 104
#
#
# 1976-Richard-Daley
# 123
#
#
# 1977-Joan-Crawford
# 89
#
#
# 1971-Hugo-Black
# 261
#
#
# 1954-Henri-Matisse
# 61
#
#
# 1906-Susan-B-Anthony
# 48
#
#
# 1990-Sammy-Davis-Jr
# 50
#
#
# 1914-John-Muir
# 48
#
#
# 1954-Anne-O-Hare-McCormick
# 60
#
#
# 1986-Kate-Smith
# 80
#
#
# 1919-Anna-H-Shaw
# 86
#
#
# 1980-Jean-Piaget
# 82
#
#
# 1966-Buster-Keaton
# 71
#
#
# 1997-Allen-Ginsberg
# 201
#
#
# 1991-Miles-Davis
# 89
#
#
# 1982-Satchel-Paige
# 56
#
#
# 1931-Ida-B-Wells
# 53
#
#
# 1967-Henry-R-Luce
# 146
#
#
# 1984-Ansel-Adams
# 37
#
#
# 1945-Ernie-Pyle
# 177
#
#
# 1952-Chaim-Weizmann
# 96
#
#
# 1973-Nancy-Mitford
# 40
#
#
# 1852-Ada-Lovelace
# 37
#
#
# 1996-Timothy-Leary
# 89
#
#
# 1919-Carnegie-Started
# 181
#
#
# 1989-Andrei-A-Gromyko
# 114
#
#
# 1965-David-O-Selznick
# 116
#
#
# 1870-Robert-E-Lee
# 42
#
#
# 1968-Robert-Francis-Kennedy
# 148
#
#
# 1900-Stephen-Crane
# 31
#
#
# 1936-John-W-Heisman
# 23
#
#
# 1998-Maureen-O-Sullivan
# 47
#
#
# 1953-Joseph-Stalin
# 133
#
#
# 1944-Alfred-E-Smith
# 155
#
#
# 1910-Tolstoy
# 114
#
#
# 1964-Cole-Porter
# 68
#
#
# 1983-Jack-Dempsey
# 139
#
#
# 1975-Haile-Selassie
# 175
#
#
# 1882-Charles-Darwin
# 70
#
#
# 1903-Emily-Warren-Roebling
# 41
#
#
# 1962-Eleanor-Roosevelt
# 148
#
#
# 1926-Harry-Houdini
# 150
#
#
# 1955-Albert-Einstein
# 119
#
#
# 1971-Coco-Chanel
# 13
#
#
# 1959-Billie-Holiday
# 38
#
#
# 1969-Coleman-Hawkins
# 60
#
#
# 1954-Frida-Kahlo
# 14
#
#
# 1911-Joseph-Pulitzer
# 346
#
#
# 1993-Carlos-Montoya
# 20
#
#
# 1947-Max-Planck
# 43
#
#
# 1985-Orson-Welles
# 139
#
#
# 1974-Earl-Warren
# 276
#
#
# 1971-Ralph-Bunche
# 139
#
#
# 1999-Hassan-II
# 120
#
#
# 1931-Knute-Rocke
# 80
#
#
# 1998-Theodore-Schultz
# 25
#
#
# 1960-Boris-Pasternak
# 75
#
#
# 1927-Victoria-Martin
# 26
#
#
# 1943-George-Washington-Carver
# 45
#
#
# 1956-Thomas-J-Watson-Sr
# 89
#
#
# 1947-Henry-Ford
# 200
#
#
# 1953-Fred-Vinson
# 98
#
#
# 1982-Leonid-Brezhnev
# 194
#
#
# 1999-King-Hussein
# 199
#
#
# 1930-Elmer-Sperry
# 36
#
#
# 1985-E-B-White
# 124
#
#
# 1959-Ethel-Barrymore
# 71
#
#
# 1986-Benny-Goodman
# 189
#
#
# 1963-W-E-B-DuBois
# 49
#
#
# 1975-Elijah-Muhammad
# 81
#
#
# 1973-Pablo-Picasso
# 389
#
#
# 1993-Federico-Fellini
# 109
#
#
# 1945-Harry-S-Truman
# 476
#
#
# 1970-De-Gaulle-Rallied
# 276
#
#
# 1995-Alfred-Eisenstaedt
# 49
#
#
# 1999-Iris-Murdoch
# 104
#
#
# 1987-Alf-Landon
# 87
#
#
# 1998-Bella-Abzug
# 150
#
#
# 1940-Scott-Fitzgerald
# 46
#
#
# 1989-Vladimir-Horowitz
# 152
#
#
# 1969-Mies-van-der-Rohe
# 126
#
#
# 1944-Ida-M-Tarbell
# 43
#
#
# 1948-John-Pershing
# 225
#
#
# 1938-Clarence-Darrow
# 133
#
#
# 1987-Primo-Levi
# 35
#
#
# 1971-Igor-Stravinsky
# 237
#
#
# 1945-George-Patton
# 122
#
#
# 1930-William-Howard-Taft
# 202
#
#
# 1935-Will-Rogers
# 103
#
#
# 1992-Shirley-Booth
# 40
#
#
# 1994-Jacqueline-Kennedy
# 226
#
#
# 1933-Ring-Lardner
# 71
#
#
# 1974-Sylvia-Plath
# 80
#
#
# 1945-FDR
# 88
#
#
# 1995-Yitzhak-Rabin
# 129
#
#
# 1960-Emily-Post
# 58
#
#
# 1984-Truman-Capote
# 92
#
#
# 1968-Upton-Sinclair
# 149
#
#
# 1994-Jan-Tinbergen
# 23
#
#
# 1957-Gerard-Swope
# 48
#
#
# 1993-Albert-Sabin
# 75
#
#
# 1955-Thomas-Mann
# 92
#
#
# 1991-Dr-Seuss
# 103
#
#
# 1877-Bedford-Forrest
# 89
#
#
# 1964-Douglas-MacArthur
# 280
#
#
# 1965-Churchill
# 240
#
#
# 1962-William-Faulkner
# 128
#
#
# 1956-Babe-Zaharias
# 68
#
#
# 1932-John-Philip-Sousa
# 52
#
#
# 1964-Herbert-Hoover
# 70
#
#
# 1961-Sam-Rayburn
# 213
#
#
# 1954-Lionel-Barrymore
# 60
#
#
# 1998-Frank-Sinatra
# 219
# 1948-Babe-Ruth
# 220
#
#
# 1947-Willa-Cather
# 39
#
#
# 1963-John-F-Kennedy
# 98
#
#
# 1975-Walker-Evans
# 47
#
#
# 1916-J-J-Hill
# 197
#
#
# 1980-Jesse-Owens
# 107
#
#
# 1948-Sergei-Eisenstein
# 19
#
#
# 1981-Robert-Moses
# 186
#
#
# 1989-Robert-Penn-Warren
# 84
#
#
# 1901-William-McKinley
# 161
#
#
# 1970-Walter-Reuther
# 23
#
#
# 1930-Balfour
# 141
#
#
# 1984-Indira-Gandhi
# 309
#
#
# 1978-Golda-Meir
# 242
#
#
# 1983-Earl-Hines
# 25
#
#
# 1974-Katharine-Cornell
# 102
#
#
# 1982-Lee-Strasberg
# 86
#
#
# 1939-Pope-Pius-XI
# 112
#
#
# 1886-Mary-Ewing-Outerbridge
# 49
#
#
# 1993-Dizzy-Gillespie
# 95
#
#
# 1910-Florence-Nightingale
# 75
#
#
# 1960-Richard-Wright
# 36
#
#
# 1986-The-Challenger
# 38
#
#
# 1992-Menachem-Begin
# 150
#
#
# 1998-Galina-Ulanova
# 32
#
#
# 1976-Max-Ernst
# 98
#
#
# 1993-Cesar-Chavez
# 78
#
#
# 1965-Adlai-Ewing-Stevenson
# 187
#
#
# 1935-Adolph-S-Ochs
# 446
#
#
# 1941-Lou-Gehrig
# 8
#
#
# 1961-Carl-G-Jung
# 92
#
#
# 1963-Robert-Frost
# 108
#
#
# 1965-Edward-R-Murrow
# 197
#
#
# 1971-Dean-Acheson
# 166
#
#
# 1986-Jorge-Luis-Borges
# 102
#
#
# 1966-Walt-Disney
# 142
#
#
# 1996-Carl-Sagan
# 58
#
#
# 1959-Ross-G-Harrison
# 14
#
#
# 1945-Jerome-Kern
# 62
#
#
# 1991-Frank-Capra
# 69
#
#
# 1987-Andres-Segovie
# 85
#
#
# 1987-Rita-Hayworth
# 62
#
#
# 1993-William-Golding
# 42
#
#
# 1932-Florenz-Ziegfeld
# 66
#
#
# 1938-Constantin-Stanislavsky
# 55

# %% [markdown]
# ## Train model

# %% [markdown]
# Now that we have our corpus ready for gensim, we can train the model. To do so, we call the function `gensim.models.Word2Vec()`. This function has a couple dozen parameters, some of which are more important than others.
#
# Here are a few major ones. Only two are MANDATORY: these are marked with an asterisk:
#
# 1. `sentences*`: This is where you provide your data. It must be in a format of iterable of iterables.
# 2. `sg`: Your choice of training algorithm. There are two standard ways of training W2V vectors -- 'skipgram' and 'CBOW'. If you enter 1 here the skip-gram is applied; otherwise, the default is CBOW.
# 3. `size*`: This is the length of your resulting word vectors. If you have a large corpus (>few billion tokens) you can go up to 100-300 dimensions. Generally word vectors with more dimensions give better results.
# 4. `window`: This is the window of context words you are training on. In other words, how many words come before and after your given word. A good number is 4 here but this can vary depending on what you are interested in. For instance, if you are more interested in embeddings that embody semantic meaning, smaller window sizes work better.
# 5. `alpha`: The learning rate of your model. If you are interested in machine learning experimentation with your vectors you may experiment with this parameter.
# 6. `seed` (int): This is the random seed for your random initialization. All deep learning models initialize the weights with random floats before training. This is a useful field if you want to replicate your experiments because giving this a seed will initialize 'randomly' deterministically.
# 7. `min_count`: This is the minimum frequency threshold. If a given word appears with lower frequency than provided it will be ignored. This is here because words with very low frequency are hard to train.
# 8. `iter`: This is the number of iterations(entire run) over the corpus, also known as epochs. Usually anything between 1-10 is ok. The trade offs are that if you have higher iterations, it will take longer to train and the model may overfit on your dataset. However, longer training will allow your vectors to perform better on tasks relevant to your dataset.
#
# Most of these settings will not concern us. As you'll see below, we are only going to use four arguments.

# %%
# let's train our model!
obit_model = gensim.models.Word2Vec(
    sentences,
    min_count=2, # default is 5; this trims the corpus for words only used once; 
    size=200, # size of NN layers; default is 100; higher for larger corpora
    workers=5) # parallel processing; needs Cython

# %% [markdown]
# Hooray! We have a trained word2vec model: `obit_model`!

# %% [markdown]
# ## Save model — and load it

# %% [markdown]
# It's often useful to save your trained model to disk so that you can reload it as needed.

# %%
obit_model.save('obit_model')

# %% [markdown]
# And you can load a model in the same way (remember this from our topic model)

# %%
old_model = gensim.models.Word2Vec.load('obit_model')

# %% [markdown]
# ## What's in the model?

# %% [markdown]
# The method `wv.vocab` allows us to see the words in our model

# %%
# take a quick look at the vocab
obit_model.wv.vocab
# Out:
# {'may': <gensim.models.keyedvectors.Vocab at 0x7f9f0efd9850>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a8410>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3b2d10>,
#  '1945': <gensim.models.keyedvectors.Vocab at 0x7f9f0ef96410>,
#  'obituary': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03d950>,
#  'hitler': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03d9d0>,
#  'fought': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03da10>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03da50>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03d890>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03d910>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03da90>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dad0>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03db10>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03db50>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03db90>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dbd0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dc10>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dc50>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dc90>,
#  'adolf': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dcd0>,
#  'one-time': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dd10>,
#  'austrian': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dd50>,
#  'vagabond': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dd90>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03ddd0>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03de10>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03de50>,
#  'dictator': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03de90>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03ded0>,
#  'germany': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03df10>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03df50>,
#  'reich': <gensim.models.keyedvectors.Vocab at 0x7f9f0f03df90>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x7f9f0f03dfd0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040050>,
#  'scourge': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040090>,
#  'europe': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0400d0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040110>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040150>,
#  'lenin': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040190>,
#  'mussolini': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0401d0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040210>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040250>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040290>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0402d0>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040310>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040350>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040390>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0403d0>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040410>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040450>,
#  'titanic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040490>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0404d0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040510>,
#  'carried': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040550>,
#  'bookish': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040590>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0405d0>,
#  'revolutionist': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040610>,
#  'pinnacle': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040650>,
#  'empire': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040690>,
#  'czars': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0406d0>,
#  'cleared': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040710>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040750>,
#  'mastery': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040790>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0407d0>,
#  'rome': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040810>,
#  'caesars': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040850>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040890>,
#  'paved': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0408d0>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x7f9f0f040910>,
#  'domination': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040950>,
#  'former': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040990>,
#  'mighty': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0409d0>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040a10>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040a50>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040a90>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040ad0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040b10>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040b50>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040b90>,
#  'strangest': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040bd0>,
#  'phenomenon': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040c10>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040c50>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040c90>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040cd0>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040d10>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040d50>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040d90>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040dd0>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040e10>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040e50>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040e90>,
#  'occupied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040ed0>,
#  'prominent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040f10>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040f50>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040f90>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x7f9f0f040fd0>,
#  'theoretician': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043050>,
#  'bolshevist': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043090>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0430d0>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043110>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043150>,
#  'socialist': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043190>,
#  'editor': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0431d0>,
#  'orator': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043210>,
#  'politician': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043250>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043290>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0432d0>,
#  'bid': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043310>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043350>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043390>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0433d0>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043410>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043450>,
#  'germans': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043490>,
#  'dreamed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0434d0>,
#  'thundered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043510>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043550>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043590>,
#  'fascism': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0435d0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043610>,
#  'challenged': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043650>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043690>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0436d0>,
#  'unleashing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043710>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043750>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043790>,
#  'emerging': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0437d0>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043810>,
#  '1918': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043850>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043890>,
#  'obscure': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0438d0>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043910>,
#  'corporal': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043950>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043990>,
#  'twenty-one': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0439d0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043a10>,
#  'supreme': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043a50>,
#  'fuehrer': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043a90>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043ad0>,
#  'subdued': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043b10>,
#  'climax': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043b50>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043b90>,
#  'unparalleled': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043bd0>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043c10>,
#  'defied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043c50>,
#  'successfully': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043c90>,
#  'humiliated': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043cd0>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043d10>,
#  'powers': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043d50>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043d90>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043dd0>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043e10>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043e50>,
#  'founded': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043e90>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043ed0>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043f10>,
#  'scores': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043f50>,
#  'millions': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043f90>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f9f0f043fd0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045050>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045090>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0450d0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045110>,
#  'cultural': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045150>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045190>,
#  'sixty-five': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0451d0>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045210>,
#  'yielded': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045250>,
#  'blandishments': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045290>,
#  'magnetism': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0452d0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f9f062d1a50>,
#  'slender': <gensim.models.keyedvectors.Vocab at 0x7f9f062d1d50>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f9f062d1dd0>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7f9f062d1910>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x7f9f0a339b10>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2bd0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2f90>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2e50>,
#  'mustache': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2b50>,
#  'shock': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2f10>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2a50>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7f9f0a3a2990>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x7f9f062e5c90>,
#  'fervor': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045310>,
#  'swept': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045350>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045390>,
#  'outstretched': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0453d0>,
#  'arms': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045410>,
#  'savior': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045450>,
#  'austria': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045490>,
#  '7,000,000': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0454d0>,
#  'inhabitants': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045510>,
#  'succumbed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045550>,
#  'helplessly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045590>,
#  'invasion': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0455d0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045610>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045650>,
#  '2,000,000': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045690>,
#  'sudeten': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0456d0>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045710>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045750>,
#  'added': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045790>,
#  'domain': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0457d0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045810>,
#  'threatened': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045850>,
#  'invade': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045890>,
#  'czechoslovakia': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0458d0>,
#  '10,000,000': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045910>,
#  'czechs': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045950>,
#  'slovaks': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045990>,
#  'tied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0459d0>,
#  'wheel': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045a10>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045a50>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045a90>,
#  'stripped': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045ad0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045b10>,
#  'defenses': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045b50>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045b90>,
#  'destroyed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045bd0>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045c10>,
#  'trembled': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045c50>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045c90>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045cd0>,
#  'irresistible': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045d10>,
#  'advance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045d50>,
#  'goose-': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045d90>,
#  'stepping': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045dd0>,
#  'nazi': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045e10>,
#  'hordes': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045e50>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045e90>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045ed0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045f10>,
#  'advent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045f50>,
#  'january': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045f90>,
#  '1933': <gensim.models.keyedvectors.Vocab at 0x7f9f0f045fd0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048050>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048090>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0480d0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048110>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048150>,
#  'dare': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048190>,
#  'challenge': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0481d0>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048210>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048250>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048290>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0482d0>,
#  'poland': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048310>,
#  'backed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048350>,
#  'anglo-french': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048390>,
#  'alliance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0483d0>,
#  'shortly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048410>,
#  'subjugation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048450>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048490>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0484d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048510>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048550>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048590>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0485d0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048610>,
#  'blow': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048650>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048690>,
#  'france': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0486d0>,
#  'england': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048710>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048750>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048790>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0487d0>,
#  'indications': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048810>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048850>,
#  'deliberately': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048890>,
#  'stake': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0488d0>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048910>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048950>,
#  'yearned': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048990>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0489d0>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048a10>,
#  'sensing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048a50>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048a90>,
#  'unleashed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048ad0>,
#  'forces': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048b10>,
#  'hatred': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048b50>,
#  'opposition': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048b90>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048bd0>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048c10>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048c50>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048c90>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048cd0>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048d10>,
#  'promises': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048d50>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048d90>,
#  'hoped': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048dd0>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048e10>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048e50>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048e90>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048ed0>,
#  'abroad': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048f10>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048f50>,
#  'reluctant': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048f90>,
#  'pursue': <gensim.models.keyedvectors.Vocab at 0x7f9f0f048fd0>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d050>,
#  'conquest': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d090>,
#  'outlined': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d0d0>,
#  'himself': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d110>,
#  'mein': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d150>,
#  'kampf': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d190>,
#  'speeches': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d1d0>,
#  'abandoned': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d210>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d250>,
#  'violation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d290>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d2d0>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d310>,
#  'integrity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d350>,
#  'munich': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d390>,
#  'marched': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d3d0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d410>,
#  'prague': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d450>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d490>,
#  'german': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d4d0>,
#  'protectorate': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d510>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d550>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d590>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d5d0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d610>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d650>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d690>,
#  'hesitate': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d6d0>,
#  'massacre': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d710>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d750>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d790>,
#  'adherents': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d7d0>,
#  'purge': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d810>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d850>,
#  '1934': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d890>,
#  'personally': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d8d0>,
#  'directed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d910>,
#  'killing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d950>,
#  'capt': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d990>,
#  'ernst': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04d9d0>,
#  'roehm': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04da10>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04da50>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04da90>,
#  'nazis': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dad0>,
#  'ventured': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04db10>,
#  'interfere': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04db50>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04db90>,
#  'closer': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dbd0>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dc10>,
#  'reichswehr': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dc50>,
#  'regime': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dc90>,
#  'insisted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dcd0>,
#  'fulfillment': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dd10>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dd50>,
#  'world-wide': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dd90>,
#  'condemnation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04ddd0>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04de10>,
#  'fed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04de50>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04de90>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04ded0>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04df10>,
#  'conquered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04df50>,
#  'jailing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04df90>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x7f9f0f04dfd0>,
#  'prisons': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050050>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050090>,
#  'camps': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0500d0>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050110>,
#  'murder': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050150>,
#  'opponents': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050190>,
#  'suspected': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0501d0>,
#  'ruthless': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050210>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050250>,
#  'jews': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050290>,
#  'persecution': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0502d0>,
#  'catholic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050310>,
#  'protestant': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050350>,
#  'churches': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050390>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0503d0>,
#  'persecuted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050410>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050450>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7f9f0f050490>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0504d0>,
#  'pastor': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050510>,
#  'niemoeller': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050550>,
#  'pre-eminent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050590>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0505d0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050610>,
#  'themselves': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050650>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050690>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0506d0>,
#  'aimed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050710>,
#  'substitution': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050750>,
#  'pagan': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050790>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0507d0>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050810>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050850>,
#  'brave': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050890>,
#  'representatives': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0508d0>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050910>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050950>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050990>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0509d0>,
#  'symbol': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050a10>,
#  'christianity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050a50>,
#  'struggling': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050a90>,
#  'maintain': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050ad0>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050b10>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050b50>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050b90>,
#  'unrest': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050bd0>,
#  'springboard': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050c10>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050c50>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050c90>,
#  'post-war': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050cd0>,
#  'smarting': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050d10>,
#  'painfully': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050d50>,
#  'humiliation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050d90>,
#  'defeat': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050dd0>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050e10>,
#  'fifteen': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050e50>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050e90>,
#  'dissension': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050ed0>,
#  'unemployment': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050f10>,
#  'supplied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050f50>,
#  'leap': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050f90>,
#  '1933.': <gensim.models.keyedvectors.Vocab at 0x7f9f0f050fd0>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054050>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054090>,
#  'disappointed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0540d0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054110>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054150>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054190>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0541d0>,
#  'accepted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054210>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054250>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054290>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0542d0>,
#  'propaganda': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054310>,
#  'maneuvered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054350>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054390>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0543d0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054410>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054450>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054490>,
#  'seizure': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0544d0>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054510>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054550>,
#  'conduct': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054590>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0545d0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054610>,
#  'sought': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054650>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054690>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0546d0>,
#  'youth': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054710>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054750>,
#  'striking': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054790>,
#  'contradictions': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0547d0>,
#  'discrepancy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054810>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054850>,
#  'exercised': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054890>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0548d0>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054910>,
#  'champion': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054950>,
#  'aryan': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054990>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0549d0>,
#  'purity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054a10>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054a50>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054a90>,
#  'von': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054ad0>,
#  'gruber': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054b10>,
#  'noted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054b50>,
#  'authority': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054b90>,
#  'hygiene': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054bd0>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054c10>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054c50>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054c90>,
#  'trial': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054cd0>,
#  'court': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054d10>,
#  '1923': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054d50>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054d90>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054dd0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054e10>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054e50>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054e90>,
#  'receding': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054ed0>,
#  'forehead': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054f10>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054f50>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054f90>,
#  'cheekbones': <gensim.models.keyedvectors.Vocab at 0x7f9f0f054fd0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056050>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056090>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0560d0>,
#  'commanding': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056110>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056150>,
#  'self-control': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056190>,
#  'instantly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0561d0>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056210>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056250>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056290>,
#  'complacency': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0562d0>,
#  'watched': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056310>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056350>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056390>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0563d0>,
#  'megalomania': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056410>,
#  'gambler': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056450>,
#  'readiness': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056490>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0564d0>,
#  'risks': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056510>,
#  'habit': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056550>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056590>,
#  'exaggeration': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0565d0>,
#  'inability': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056610>,
#  'grasp': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056650>,
#  'implications': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056690>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0566d0>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056710>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056750>,
#  'significance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056790>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0567d0>,
#  'deeds': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056810>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056850>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056890>,
#  'coolness': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0568d0>,
#  'displayed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056910>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056950>,
#  'moments': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056990>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0569d0>,
#  'outbursts': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056a10>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056a50>,
#  'temper': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056a90>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056ad0>,
#  'occasions': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056b10>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056b50>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056b90>,
#  'hysterics': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056bd0>,
#  'weapon': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056c10>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056c50>,
#  'possessed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056c90>,
#  'uncanny': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056cd0>,
#  'shrewdness': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056d10>,
#  'estimate': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056d50>,
#  'psychology': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056d90>,
#  'masses': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056dd0>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056e10>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056e50>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056e90>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056ed0>,
#  'swaying': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056f10>,
#  'emotions': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056f50>,
#  'enhanced': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056f90>,
#  'contempt': <gensim.models.keyedvectors.Vocab at 0x7f9f0f056fd0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b050>,
#  'whom': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b090>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b0d0>,
#  'flock': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b110>,
#  'sheep': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b150>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b190>,
#  'convinced': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b1d0>,
#  'minority': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b210>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b250>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b290>,
#  'constituted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b2d0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b310>,
#  'shrewd': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b350>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b390>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b3d0>,
#  'heaven': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b410>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b450>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b490>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b4d0>,
#  'vice': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b510>,
#  'versa': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b550>,
#  'existence': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b590>,
#  'paradise': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b5d0>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b610>,
#  'unbounded': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b650>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b690>,
#  'merciless': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b6d0>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b710>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b750>,
#  'psychologists': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b790>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b7d0>,
#  'closely': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b810>,
#  'emanated': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b850>,
#  'poverty': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b890>,
#  'frustrations': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b8d0>,
#  'inn': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b910>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b950>,
#  'frontier': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b990>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05b9d0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ba10>,
#  '1889.': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ba50>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ba90>,
#  'alois': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bad0>,
#  'illegitimate': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bb10>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bb50>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bb90>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bbd0>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bc10>,
#  'peasant': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bc50>,
#  'entered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bc90>,
#  'customs': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bcd0>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bd10>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bd50>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bd90>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bdd0>,
#  'niece': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05be10>,
#  'ward': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05be50>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05be90>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bed0>,
#  'younger': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bf10>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bf50>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bf90>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05bfd0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e050>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e090>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e0d0>,
#  'marriages': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e110>,
#  'contracted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e150>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e190>,
#  'pulmonary': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e1d0>,
#  'hemorrhage': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e210>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e250>,
#  '66.': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e290>,
#  'wives': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e2d0>,
#  'weak': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e310>,
#  'chests': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e350>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e390>,
#  'brothers': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e3d0>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e410>,
#  'childhood': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e450>,
#  'committed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e490>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e4d0>,
#  'half-brother': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e510>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e550>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e590>,
#  'suffered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e5d0>,
#  'lung': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e610>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e650>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e690>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e6d0>,
#  'eccentrics': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e710>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e750>,
#  'definite': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e790>,
#  'tendencies': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e7d0>,
#  'illness': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e810>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e850>,
#  'instability': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e890>,
#  'adherent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e8d0>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e910>,
#  'fervent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e950>,
#  'supporter': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e990>,
#  'monarchy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05e9d0>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ea10>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ea50>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ea90>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ead0>,
#  'historic': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05eb10>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05eb50>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05eb90>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ebd0>,
#  'races': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ec10>,
#  'franz': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ec50>,
#  'josef': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ec90>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ecd0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ed10>,
#  'resented': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ed50>,
#  'insistence': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ed90>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05edd0>,
#  'defy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ee10>,
#  'openly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ee50>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ee90>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05eed0>,
#  'idling': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ef10>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ef50>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05ef90>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x7f9f0f05efd0>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062050>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062090>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0620d0>,
#  'linz': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062110>,
#  'stayed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062150>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062190>,
#  'catered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0621d0>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062210>,
#  'friendless': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062250>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062290>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0622d0>,
#  'earning': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062310>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062350>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062390>,
#  'unprepared': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0623d0>,
#  'battle': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062410>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062450>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062490>,
#  'examinations': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0624d0>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062510>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062550>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062590>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0625d0>,
#  'courses': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062610>,
#  'drawing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062650>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062690>,
#  'betook': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0626d0>,
#  'vienna': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062710>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062750>,
#  'admission': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062790>,
#  'academy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0627d0>,
#  'arts': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062810>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062850>,
#  'architect': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062890>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0628d0>,
#  'drawings': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062910>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062950>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062990>,
#  'mediocre': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0629d0>,
#  'denied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062a10>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062a50>,
#  'qualification': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062a90>,
#  '1909': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062ad0>,
#  'outbreak': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062b10>,
#  'wretched': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062b50>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062b90>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062bd0>,
#  'beggars': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062c10>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062c50>,
#  'nights': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062c90>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062cd0>,
#  'benches': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062d10>,
#  'harassed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062d50>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062d90>,
#  'outcast': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062dd0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062e10>,
#  'monastery': <gensim.models.keyedvectors.Vocab at 0x7f9f0f062e50>,
# ...
#  'autobiography': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064510>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064550>,
#  'twenty-fifth': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064590>,
#  'spoiled': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0645d0>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064610>,
#  'sensitive': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064650>,
#  'ego': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064690>,
#  'restless': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0646d0>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064710>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064750>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064790>,
#  'passionately': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0647d0>,
#  'impression': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064810>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064850>,
#  'attain': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064890>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0648d0>,
#  'achievements': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064910>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064950>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064990>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0649d0>,
#  'politics': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064a10>,
#  'ruling': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064a50>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064a90>,
#  'shy': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064ad0>,
#  'beaten': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064b10>,
#  'transformed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064b50>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064b90>,
#  'conversation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064bd0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064c10>,
#  'matters': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064c50>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064c90>,
#  'loosen': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064cd0>,
#  'torrent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064d10>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064d50>,
#  'lips': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064d90>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064dd0>,
#  'formed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064e10>,
#  'friendships': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064e50>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064e90>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064ed0>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064f10>,
#  'communicated': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064f50>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064f90>,
#  'jeered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f064fd0>,
#  'acquaintances': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069050>,
#  'wept': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069090>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0690d0>,
#  'courage': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069110>,
#  'disintegration': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069150>,
#  'austro-': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069190>,
#  'hungarian': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0691d0>,
#  'foresaw': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069210>,
#  'evidences': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069250>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069290>,
#  'considering': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0692d0>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069310>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069350>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069390>,
#  'workers': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0693d0>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069410>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069450>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069490>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0694d0>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069510>,
#  'expressed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069550>,
#  'otto': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069590>,
#  'collaborators': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0695d0>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069610>,
#  '1930': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069650>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069690>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0696d0>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069710>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069750>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069790>,
#  'consideration': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0697d0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069810>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069850>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069890>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0698d0>,
#  'elements': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069910>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069950>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069990>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0699d0>,
#  'dividing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069a10>,
#  'mankind': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069a50>,
#  'inferior': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069a90>,
#  'divided': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069ad0>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069b10>,
#  'beings': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069b50>,
#  'stood': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069b90>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069bd0>,
#  'superman': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069c10>,
#  'achieving': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069c50>,
#  'principles': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069c90>,
#  'destined': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069cd0>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069d10>,
#  'oppose': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069d50>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069d90>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069dd0>,
#  'survival': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069e10>,
#  'peoples': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069e50>,
#  'chosen': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069e90>,
#  'destiny': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069ed0>,
#  'immersed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069f10>,
#  'materialism': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069f50>,
#  'dominated': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069f90>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7f9f0f069fd0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c050>,
#  'regarded': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c090>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c0d0>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c110>,
#  'violated': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c150>,
#  'governing': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c190>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c1d0>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c210>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c250>,
#  'remained': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c290>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c2d0>,
#  'threw': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c310>,
#  'principle': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c350>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c390>,
#  'proclaimed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c3d0>,
#  'desired': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c410>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c450>,
#  'incorporation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c490>,
#  'temporarily': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c4d0>,
#  'tactical': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c510>,
#  'maneuver': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c550>,
#  'repeatedly': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c590>,
#  'bolshevism': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c5d0>,
#  'treaty': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c610>,
#  'non-': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c650>,
#  'aggression': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c690>,
#  'midst': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c6d0>,
#  'polish': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c710>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c750>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c790>,
#  '1939.': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c7d0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c810>,
#  '1913': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c850>,
#  'supported': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c890>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c8d0>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c910>,
#  'painter': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c950>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c990>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06c9d0>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ca10>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ca50>,
#  'viennese': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ca90>,
#  'engineer': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cad0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cb10>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cb50>,
#  'contacts': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cb90>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cbd0>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cc10>,
#  'struck': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cc50>,
#  'wrangles': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cc90>,
#  'drifted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ccd0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cd10>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cd50>,
#  'employment': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cd90>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cdd0>,
#  'disclosed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ce10>,
#  'prediction': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ce50>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ce90>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06ced0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cf10>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cf50>,
#  'miserable': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cf90>,
#  'hopeless': <gensim.models.keyedvectors.Vocab at 0x7f9f0f06cfd0>,
#  'deliverance': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070050>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070090>,
#  'lifted': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0700d0>,
#  'obscurity': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070110>,
#  'exaltation': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070150>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070190>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0701d0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070210>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070250>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070290>,
#  'overcome': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0702d0>,
#  'storm': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070310>,
#  'enthusiasm': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070350>,
#  'fell': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070390>,
#  'knees': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0703d0>,
#  'thanked': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070410>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070450>,
#  'doctors': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070490>,
#  'rejected': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0704d0>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070510>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070550>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070590>,
#  'weakness': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0705d0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070610>,
#  'volunteered': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070650>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070690>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0706d0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070710>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070750>,
#  'dispatch': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070790>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0707d0>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070810>,
#  'parcels': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070850>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070890>,
#  'recognized': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0708d0>,
#  'superiors': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070910>,
#  'rewarded': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070950>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070990>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0709d0>,
#  'eccentric': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070a10>,
#  'comrades': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070a50>,
#  'replied': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070a90>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070ad0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070b10>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070b50>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070b90>,
#  'seriously': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070bd0>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070c10>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070c50>,
#  'rank': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070c90>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070cd0>,
#  'viewed': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070d10>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070d50>,
#  'collapse': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070d90>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070dd0>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070e10>,
#  'enraged': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070e50>,
#  'revolutionists': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070e90>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070ed0>,
#  'kaiser': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070f10>,
#  'marshal': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070f50>,
#  'hindenburg': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070f90>,
#  'suppress': <gensim.models.keyedvectors.Vocab at 0x7f9f0f070fd0>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072050>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072090>,
#  'civilian': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0720d0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072110>,
#  'officially': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072150>,
#  'demobilized': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072190>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f9f0f0721d0>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072210>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072250>,
#  'begun': <gensim.models.keyedvectors.Vocab at 0x7f9f0f072290>,
#  ...}

# %% [markdown]
# ## Let's play!

# %% [markdown]
# ### Similarity

# %% [markdown]
# Adolf Hitler has one of the longest obits in the corpus. word2vec can tell us which words, according to its model, are most similar to any other. We call `model.wv.most_similar("word", topn=number of similar words)`. Let's try `hitler`

# %%
# testing some basic functions

# basic similarity
obit_model.wv.most_similar("hitler", topn=10)
# Out:
# [('stalin', 0.9436033964157104),
#  ('mao', 0.926986038684845),
#  ('lenin', 0.914769172668457),
#  ('ho', 0.9062485098838806),
#  ('soprano', 0.8869476914405823),
#  ('segovia', 0.8853384256362915),
#  ('1824', 0.8807531595230103),
#  ('m-g-m', 0.8777264952659607),
#  ('ernst', 0.8767301440238953),
#  ('franco', 0.8766900300979614)]

# %% [markdown]
# Let's think about the results. `stalin` and `mao` make intuitive sense: they are the two mid-twentieth-century authoritarian figures most often compared to Hitler. But what's `irgun`? It's the name of a Zionist paramilitary organization, designated as a terrorist organization by the United Nations, that existed from 1933-1948, during Hitler's rise and fall, and which used violent means to make way for Jews in Palestine by forcing out Palestinians. Our model's parallel invites our critical analysis: rather than take these results as *true*, we need to reflect, in part through turning to obits themselves and close reading them, on how the model arrives at its results, and what they might imply.
#
# **Remember**: everything the model knows it knows from our corpus. What we're learning are assumptions *immanent* to the corpus.

# %% [markdown]
# We can choose specific words to compare with `model.wv.similarity(w1="word_one",w2="word_two")`
#
# Let's try with two of Hitler's contemporaries: Marilyn Monroe and Charles Lindbergh. The latter was a famous pilot who was also a Nazi sympathizer and briefly contemplated a political career, a possibility pursued in the counterfactual novel, *The Plot Against America*, which became an HBO show of the same name.

# %%
# similarity b/t two words

print(obit_model.wv.similarity(w1="hitler",w2="marilyn"))
print(obit_model.wv.similarity(w1="hitler",w2="lindbergh"))
# Out:
# 0.6260597
# 0.87227595

# %% [markdown]
# As expected, the model believes Lindbergh is more similar to Hitler than Monroe.

# %% [markdown]
# ### Analogy

# %% [markdown]
# We can also play with analogy tasks. The commonly seen task is:
#
# 'Man is to King as Woman is to ____?'
#
# The general structure is:
# `A is to A\*  as  B is to B\*`
#
# gensim provides two different ways of implementing this task. You may be familiar with the the additive version also called the 3CosAdd method:
#
# $$\underset{b*\in V}{\textrm{arg max}} (cos(b*,b) - cos(b*,a) + cos(b*,a*))$$
#
# This reflects the abstraction of Woman - Man + King. In this maximization, we are searching which word vector will allow us to produce the highest value in this equation.
#
# We can implement this method with a built-in function. Positive here refers to words that give the positive contribution to similarity (nominator), and negative refers to words that contribute negatively (denominatory). Here's the additive method.

# %%
# analogies
# format is: "man is to president as woman is to ???"

result = obit_model.wv.most_similar(positive=['woman', 'president'], negative=['man'])
print("{}: {:.4f}".format(*result[0])) # this prints the top result
# Out:
# secretary: 0.9030

# %% [markdown]
# Man is to woman as president is to...secretary!? Ah, the bias of the model....

# %% [markdown]
# ## There's so much more!

# %% [markdown]
# gensim has quite a few built-in tools, and it's worth taking some time to see what's available. Check the documentation here: [https://radimrehurek.com/gensim/models/keyedvectors.html](https://radimrehurek.com/gensim/models/keyedvectors.html)

# %% [markdown]
# ## Your turn!

# %% [markdown]
# Play with word2vec in the code cells below, following the prompts.

# %%
# choose a word and find the 10 words most similar to it

obit_model.wv.most_similar("marilyn", topn=10)
# Out:
# [('sarah', 0.984088659286499),
#  ('krebs', 0.9830100536346436),
#  ('conan', 0.9822401404380798),
#  ('johnny', 0.9812618494033813),
#  ('albin', 0.9808303117752075),
#  ('shirley', 0.9805138111114502),
#  ('orson', 0.9801497459411621),
#  ('birth-control', 0.9792305827140808),
#  ('van', 0.9786124229431152),
#  ('gene', 0.9783428907394409)]

# %% [markdown]
# Do the results above make sense? Reflect on them. How does attention to the corpus—its particular qualities—help explain what seems to work and what is harder to make sense of?
#
# #### ANSWER HERE

# %%
# build an analogy after the model "Man is to King as Woman is to ___". Try with various possibilities.

result = obit_model.wv.most_similar(positive=['man', 'politics'], negative=['woman'])
print("{}: {:.4f}".format(*result[0])) # this prints the top result
# Out:
# possible: 0.8554

# %% [markdown]
# In my experimenting, I found that analogies often don't work terribly well with this corpus. Did they work for you? Why, do you think?
#
# The corpus is too small for word2vec to work well

# %%
# investigate the documentation—https://radimrehurek.com/gensim/models/keyedvectors.html—
# and choose a method we haven't yet explored in this notebook

print(obit_model.doesnt_match("hitler mao marilyn stalin".split()))
# Out:
# marilyn
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %% [markdown]
# ## BONUS: Visualization

# %% [markdown]
# Find below some code you can use to make visualizations from your word2vec model. We can't visualize all the many dimensions in our model, so we need to reduce them to two dimensions for our meager human brains. We do that with something called principal component analysis (PCA).
#
# Don't worry about the details for now. This is just a fun way to take a look at the output of our model.
#
# **Remember**: Our visualization reduces MANY dimensions to two, so a lot of information is lost.

# %%
### Let's do some visualization ###

import numpy as np

# Get the interactive Tools for Matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.decomposition import PCA

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.wv.vocab.keys()), sample)
        else:
            words = [ word for word in model.wv.vocab ]
        
    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]
    
    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)

# %%
display_pca_scatterplot(obit_model, ['hitler','stalin','lindbergh','marilyn','picasso'])

# display_pca_scatterplot(ccp_model, sample=20)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# <img src="data:image/png;base64,..." width="600">
