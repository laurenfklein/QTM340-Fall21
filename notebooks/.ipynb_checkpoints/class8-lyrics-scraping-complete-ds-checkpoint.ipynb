# %%
# import libraries we'll need

import requests
from bs4 import BeautifulSoup

# %%
# get the contents of the candidate playlist page

resp = requests.get("https://www.nytimes.com/interactive/2019/08/19/us/politics/presidential-campaign-songs-playlists.html")

# %%
# convert it to string and just make sure it worked
html_str = resp.text

html_str
# Out:
# '<!DOCTYPE html>\n<!--[if (gt IE 9)|!(IE)]> <!--><html lang="en" class="no-js page-interactive section-us page-theme-standard template-minimal tone-feature page-interactive-default limit-small layout-xlarge app-interactive" itemid="https://www.nytimes.com/interactive/2019/08/19/us/politics/presidential-campaign-songs-playlists.html" itemtype="http://schema.org/NewsArticle" itemscope xmlns:og="http://opengraphprotocol.org/schema/"><!--<![endif]-->\n<!--[if IE 9]> <html lang="en" class="no-js ie9 lt-ie10 page-interactive section-us page-theme-standard template-minimal tone-feature page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<!--[if IE 8]> <html lang="en" class="no-js ie8 lt-ie10 lt-ie9 page-interactive section-us page-theme-standard template-minimal tone-feature page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<!--[if (lt IE 8)]> <html lang="en" class="no-js lt-ie10 lt-ie9 lt-ie8 page-interactive section-us page-theme-standard template-minimal tone-feature page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<head>\n<script>\nif (document.location.search.indexOf(\'nytapp=true\') > -1) document.documentElement.classList.add(\'nyt-hide-shell\');\nvar userAgent = window.navigator.userAgent || window.navigator.vendor || window.opera;\nvar inAndroid = userAgent.indexOf(\'nyt_android\') !== -1;\nvar iniOS = userAgent.indexOf(\'nytios\') !== -1;\nif (inAndroid || iniOS) document.documentElement.classList.add(\'nyt-hide-shell\');\n</script>\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />\n<link rel="shortcut icon" href="https://static01.nyt.com/favicon.ico" />\n<link rel="apple-touch-icon-precomposed" sizes="144×144" href="https://static01.nyt.com/images/icons/ios-ipad-144x144.png" />\n<link rel="apple-touch-icon-precomposed" sizes="114×114" href="https://static01.nyt.com/images/icons/ios-iphone-114x144.png" />\n<link rel="apple-touch-icon-precomposed" href="https://static01.nyt.com/images/icons/ios-default-homescreen-57x57.png" />\n<meta property="fb:app_id" content="9869919170" />\n<meta name="twitter:site" value="@nytimes" />\n<meta name="sourceApp" content="nyt-v5" />\n<meta name="applicationName" content="newsdev" id="applicationName" />\n<meta name="foundation-build-id" content="nyt-v5" id="foundation-build-id" />\n<link rel="canonical" href="https://www.nytimes.com/interactive/2019/08/19/us/politics/presidential-campaign-songs-playlists.html" />\n<meta name="PT" content="Multimedia" />\n<meta name="PST" content="Interactive" />\n<meta name="tom" content="interactive_feature" />\n<meta name="hdl" content="What Does Campaign Rally Music Say About a Candidate?" />\n<meta name="slug" content="presidential-campaign-songs-playlists" />\n<meta name="lp" content="Presidential campaigns have a sound. We analyzed the playlists of 10 contenders to see how the songs aligned with the messages." />\n<meta name="col" content="" id="column-name" />\n<meta name="dfp-ad-unit-path" content="us/politics" />\n\n<meta name="keywords" content="Presidential Election of 2020,Music,Harris, Kamala D,Trump, Donald J,O\'Rourke, Beto,Buttigieg, Pete (1982- ),Castro, Julian,Biden, Joseph R Jr,Gillibrand, Kirsten E,Sanders, Bernard,Warren, Elizabeth,United States Politics and Government" />\n\n<meta property="article:collection" content="https://static01.nyt.com/services/json/sectionfronts/us/index.jsonp" />\n<meta name="DISPLAYDATE" content="Aug. 19, 2019" />\n<meta name="dat" content="Aug. 19, 2019" />\n<meta name="author" content="Astead W. Herndon" /><meta name="author" content="Gabriel Gianordoli" /><meta name="author" content="Umi Syam" /><meta name="author" content="Jon Caramanica" /><meta  ...

# %%
# load it into beautiful soup

document = BeautifulSoup(html_str, "html.parser")

# %%
# find all the song title tags and see what they look like

title_tags = document.find_all("span", attrs={"class": "song-title"})

title_tags
# Out:
# [<span class="song-title">Respect</span>,
#  <span class="song-title">9 to 5</span>,
#  <span class="song-title">Stand by Me</span>,
#  <span class="song-title">Work That</span>,
#  <span class="song-title">High Hopes</span>,
#  <span class="song-title">Dance to the Music</span>,
#  <span class="song-title">Love Train</span>,
#  <span class="song-title">I’m Coming Out</span>,
#  <span class="song-title">One Nation Under a Groove</span>,
#  <span class="song-title">Rocking in the Free World</span>,
#  <span class="song-title">My Shot</span>,
#  <span class="song-title">Superwoman</span>,
#  <span class="song-title">Good as Hell</span>,
#  <span class="song-title">Higher Ground</span>,
#  <span class="song-title">Lovely Day</span>,
#  <span class="song-title">California Love </span>,
#  <span class="song-title">Run the World (Girls)</span>,
#  <span class="song-title">Think</span>,
#  <span class="song-title">Dis Generation</span>,
#  <span class="song-title">Girl on Fire</span>,
#  <span class="song-title">Revolution</span>,
#  <span class="song-title">Power to the People</span>,
#  <span class="song-title">Made in the USA</span>,
#  <span class="song-title">Believer</span>,
#  <span class="song-title">Latinoamérica</span>,
#  <span class="song-title">God Bless the USA</span>,
#  <span class="song-title">I Love Rock ’n Roll</span>,
#  <span class="song-title">Confident</span>,
#  <span class="song-title">I Wanna Dance with Somebody (Who Loves Me)</span>,
#  <span class="song-title">Empire State of Mind </span>,
#  <span class="song-title">Dog Days Are Over</span>,
#  <span class="song-title">Born This Way</span>,
#  <span class="song-title">Baila Esta Cumbia</span>,
#  <span class="song-title">Macho Man</span>,
#  <span class="song-title">Everyday People</span>,
#  <span class="song-title">Clampdown</span>,
#  <span class="song-title">Love Train</span>,
#  <span class="song-title">The Edge of Glory</span>,
#  <span class="song-title">Learn to Live</span>,
#  <span class="song-title">Under Pressure</span>,
#  <span class="song-title">Country Nation</span>,
#  <span class="song-title">Yes We Can Can</span>,
#  <span class="song-title">Baba O’Riley</span>,
#  <span class="song-title">Love on Top</span>,
#  <span class="song-title">Soar</span>,
#  <span class="song-title">Feeling Good</span>,
#  <span class="song-title">Stand up for Something </span>,
#  <span class="song-title">Fire</span>,
#  <span class="song-title">Clampdown</span>,
#  <span class="song-title">Mi Tierra</span>,
#  <span class="song-title">Let Love Rule</span>,
#  <span class="song-title">Third Eye</span>,
#  <span class="song-title">The Times They Are a-Changin’</span>,
#  <span class="song-title">High Hopes</span>,
#  <span class="song-title">Da Da Ding </span>,
#  <span class="song-title">Never Going Back Again</span>,
#  <span class="song-title">Move on Up</span>,
#  <span class="song-title">Ain’t No Man</span>,
#  <span class="song-title">Come Alive </span>,
#  <span class="song-title">Brooklyn Go Hard</span>,
#  <span class="song-title">On the Road Again (Live)</span>,
#  <span class="song-title">Revolution</span>,
#  <span class="song-title">Uprising</span>,
#  <span class="song-title">Revolution</span>,
#  <span class="song-title">The Revolution Starts...</span>,
#  <span class="song-title">Power to the People</span>,
#  <span class="song-title">Takin’ It to the Streets</span>,
#  <span class="song-title">Heroes </span>,
#  <span class="song-title">All We Ever Knew</span>,
#  <span class="song-title">(Your Love Keeps Lifting Me) Higher &amp; Higher</span>,
#  <span class="song-title">Rollercoaster</span>,
#  <span class="song-title">Sweet Home Alabama</span>,
#  <span class="song-title">Tiny Dancer</span>,
#  <span class="song-title">Eye of the Tiger</span>,
#  <span class="song-title">God Bless the USA</span>,
#  <span class="song-title">Rocking in the Free World</span>,
#  <span class="song-title">American Girl</span>,
#  <span class="song-title">Keep Ya Head Up</span>,
#  <span class="song-title">O-o-h Child</span>,
#  <span class="song-title">Dance to the Music</span>,
#  <span class="song-title">Love Train</span>,
#  <span class="song-title">I Wanna Dance with Somebody (Who Loves Me)</span>,
#  <span class="song-title">California Love </span>,
#  <span class="song-title">Dis Generation</span>,
#  <span class="song-title">Girl on Fire</span>,
#  <span class="song-title">God Is a Woman</span>,
#  <span class="song-title">Love on Top</span>,
#  <span class="song-title">Redbone</span>,
#  <span class="song-title">Choices (Yup)</span>,
#  <span class="song-title">Just a Girl</span>,
#  <span class="song-title">Try a Little Tenderness</span>,
#  <span class="song-title">Ladies First</span>,
#  <span class="song-title">King of Anything</span>,
#  <span class="song-title">Bidi Bidi Bom Bom</span>,
#  <span class="song-title">Higher Ground</span>,
#  <span class="song-title">Freedom (Homecoming Live)</span>,
#  <span class="song-title">We Take Care of Our Own</span>,
#  <span class="song-title">(Your Love Keeps Lifting Me) Higher &amp; Higher</span>,
#  <span class="song-title">Made in the USA</span>,
#  <span class="song-title">Tightrope </span>,
#  <span class="song-title">I’ve Been Everywhere</span>,
#  <span class="song-title">Mi Tierra</span>,
#  <span class="song-title">Let Love Rule</span>,
#  <span class="song-title">Third Eye</span>,
#  <span class="song-title">The Times They Are a-Changin’</span>,
#  <span class="song-title">Da Da Ding </span>,
#  <span class="song-title">High Hopes</span>,
#  <span class="song-title">Baba O’Riley</span>,
#  <span class="song-title">River</span>,
#  <span class="song-title">The Underdog</span>,
#  <span class="song-title">You Are My Rock n’ Roll Star</span>,
#  <span class="song-title">Roadrunner</span>,
#  <span class="song-title">American Pie</span>,
#  <span class="song-title">The Distance</span>,
#  <span class="song-title">Never Going Back Again</span>,
#  <span class="song-title">Move on Up</span>,
#  <span class="song-title">Ain’t No Man</span>,
#  <span class="song-title">Come Alive </span>,
#  <span class="song-title">Brooklyn Go Hard</span>,
#  <span class="song-title">Disco Inferno </span>,
#  <span class="song-title">Runaway (U &amp; I)</span>,
#  <span class="song-title">America</span>,
#  <span class="song-title">Make a Change</span>,
#  <span class="song-title">On the Road Again (Live)</span>,
#  <span class="song-title">I’m Coming Out</span>,
#  <span class="song-title">Could It Be I’m Falling in Love</span>,
#  <span class="song-title">Keep Going</span>,
#  <span class="song-title">Good Times</span>,
#  <span class="song-title">All I Do</span>,
#  <span class="song-title">Teardrops</span>,
#  <span class="song-title">The Weight</span>,
#  <span class="song-title">Learn to Live</span>,
#  <span class="song-title">Sweet Home Alabama</span>,
#  <span class="song-title">Tiny Dancer</span>,
#  <span class="song-title">Eye of the Tiger</span>,
#  <span class="song-title">All Summer Long</span>,
#  <span class="song-title">Candle in the Wind</span>,
#  <span class="song-title">Respect</span>,
#  <span class="song-title">9 to 5</span>,
#  <span class="song-title">Stand by Me</span>,
#  <span class="song-title">Work That</span>,
#  <span class="song-title">High Hopes</span>,
#  <span class="song-title">Dance to the Music</span>,
#  <span class="song-title">Love Train</span>,
#  <span class="song-title">I’m Coming Out</span>,
#  <span class="song-title">Rocking in the Free World</span>,
#  <span class="song-title">My Shot</span>,
#  <span class="song-title">One Nation Under a Groove</span>,
#  <span class="song-title">Superwoman</span>,
#  <span class="song-title">Good as Hell</span>,
#  <span class="song-title">Higher Ground</span>,
#  <span class="song-title">Lovely Day</span>,
#  <span class="song-title">California Love </span>,
#  <span class="song-title">Think</span>,
#  <span class="song-title">Dis Generation</span>,
#  <span class="song-title">Girl on Fire</span>,
#  <span class="song-title">Run the World (Girls)</span>,
#  <span class="song-title">Revolution</span>,
#  <span class="song-title">Power to the People</span>,
#  <span class="song-title">Made in the USA</span>,
#  <span class="song-title">Believer</span>,
#  <span class="song-title">Latinoamérica</span>,
#  <span class="song-title">God Bless the USA</span>,
#  <span class="song-title">I Love Rock ’n Roll</span>,
#  <span class="song-title">Confident</span>,
#  <span class="song-title">I Wanna Dance with Somebody (Who Loves Me)</span>,
#  <span class="song-title">Empire State of Mind </span>,
#  <span class="song-title">Dog Days Are Over</span>,
#  <span class="song-title">Born This Way</span>,
#  <span class="song-title">Baila Esta Cumbia</span>,
#  <span class="song-title">Macho Man</span>,
#  <span class="song-title">Everyday People</span>,
#  <span class="song-title">Clampdown</span>,
#  <span class="song-title">Love Train</span>,
#  <span class="song-title">The Edge of Glory</span>,
#  <span class="song-title">Learn to Live</span>,
#  <span class="song-title">Under Pressure</span>,
#  <span class="song-title">Country Nation</span>,
#  <span class="song-title">Yes We Can Can</span>,
#  <span class="song-title">Baba O’Riley</span>,
#  <span class="song-title">Love on Top</span>,
#  <span class="song-title">Soar</span>,
#  <span class="song-title">Feeling Good</span>,
#  <span class="song-title">Stand up for Something </span>]

# %%
# now let's make a dictionary in the format {song title, artist}

song_dict = {} 

for title in title_tags:
    # get the string associated w/ the tag
    song_title = title.string
    # while we're looking at that title, look for the next sibling
    artist_name = title.find_next_sibling('span')
    # add it to the dict (and be sure to add only the string)
    song_dict[song_title] = artist_name.string
    
song_dict
# Out:
# {'Respect': 'Aretha Franklin',
#  '9 to 5': 'Dolly Parton',
#  'Stand by Me': 'Ben E. King',
#  'Work That': 'Mary J. Blige',
#  'High Hopes': 'Panic! at the Disco',
#  'Dance to the Music': 'Sly & the Family Stone',
#  'Love Train': 'The O’Jays',
#  'I’m Coming Out': 'Diana Ross',
#  'One Nation Under a Groove': 'Funkadelic',
#  'Rocking in the Free World': 'Neil Young',
#  'My Shot': 'Lin-Manuel Miranda',
#  'Superwoman': 'Alicia Keys',
#  'Good as Hell': 'Lizzo',
#  'Higher Ground': 'Stevie Wonder',
#  'Lovely Day': 'Bill Withers',
#  'California Love ': 'Tupac Shakur',
#  'Run the World (Girls)': 'Beyoncé',
#  'Think': 'Aretha Franklin',
#  'Dis Generation': 'A Tribe Called Quest',
#  'Girl on Fire': 'Alicia Keys',
#  'Revolution': 'Toots and the Maytals',
#  'Power to the People': 'John Lennon',
#  'Made in the USA': 'Demi Lovato',
#  'Believer': 'Imagine Dragons',
#  'Latinoamérica': 'Calle 13',
#  'God Bless the USA': 'Lee Greenwoood',
#  'I Love Rock ’n Roll': 'Joan Jett & the Blackhearts',
#  'Confident': 'Demi Lovato',
#  'I Wanna Dance with Somebody (Who Loves Me)': 'Whitney Houston',
#  'Empire State of Mind ': 'Jay-Z (featuring Alicia Keys)',
#  'Dog Days Are Over': 'Florence + the Machine',
#  'Born This Way': 'Lady Gaga',
#  'Baila Esta Cumbia': 'Selena',
#  'Macho Man': 'Village People',
#  'Everyday People': 'Joan Jett & the Blackhearts',
#  'Clampdown': 'The Clash',
#  'The Edge of Glory': 'Lady Gaga',
#  'Learn to Live': 'Darius Rucker',
#  'Under Pressure': 'Queen',
#  'Country Nation': 'Brad Paisley',
#  'Yes We Can Can': 'The Pointer Sisters',
#  'Baba O’Riley': 'The Who',
#  'Love on Top': 'Beyoncé',
#  'Soar': 'Christina Aguilera',
#  'Feeling Good': 'Jennifer Hudson',
#  'Stand up for Something ': 'Andra Day (featuring Common)',
#  'Fire': 'Timeflies',
#  'Mi Tierra': 'Gloria Estefan',
#  'Let Love Rule': 'Lenny Kravitz',
#  'Third Eye': 'Florence + the Machine',
#  'The Times They Are a-Changin’': 'Tracy Chapman',
#  'Da Da Ding ': 'GENER8ION (featuring Gizzle)',
#  'Never Going Back Again': 'Fleetwood Mac',
#  'Move on Up': 'Curtis Mayfield',
#  'Ain’t No Man': 'The Avett Brothers',
#  'Come Alive ': 'Years & Years with Jess Glynne',
#  'Brooklyn Go Hard': 'Jay-Z',
#  'On the Road Again (Live)': 'Willie Nelson',
#  'Uprising': 'Muse',
#  'The Revolution Starts...': 'Steve Earle',
#  'Takin’ It to the Streets': 'The Doobie Brothers',
#  'Heroes ': 'David Bowie',
#  'All We Ever Knew': 'The Head and the Heart',
#  '(Your Love Keeps Lifting Me) Higher & Higher': 'Jackie Wilson',
#  'Rollercoaster': 'Bleachers',
#  'Sweet Home Alabama': 'Lynyrd Skynyrd',
#  'Tiny Dancer': 'Elton John',
#  'Eye of the Tiger': 'Survivor',
#  'American Girl': 'Tom Petty and the Heartbreakers',
#  'Keep Ya Head Up': 'Tupac Shakur',
#  'O-o-h Child': 'Five Stairsteps',
#  'God Is a Woman': 'Ariana Grande',
#  'Redbone': 'Childish Gambino',
#  'Choices (Yup)': 'E-40',
#  'Just a Girl': 'No Doubt',
#  'Try a Little Tenderness': 'Otis Redding',
#  'Ladies First': 'Queen Latifah',
#  'King of Anything': 'Sara Bareilles',
#  'Bidi Bidi Bom Bom': 'Selena',
#  'Freedom (Homecoming Live)': 'Beyoncé',
#  'We Take Care of Our Own': 'Bruce Springsteen',
#  'Tightrope ': 'Janelle Monáe',
#  'I’ve Been Everywhere': 'Johnny Cash',
#  'River': 'Leon Bridges',
#  'The Underdog': 'Spoon',
#  'You Are My Rock n’ Roll Star': 'Fragile Gang',
#  'Roadrunner': 'The Modern Lovers',
#  'American Pie': 'Shea Diamond',
#  'The Distance': 'Cake',
#  'Disco Inferno ': 'The Trammps',
#  'Runaway (U & I)': 'Galantis',
#  'America': 'Simon & Garfunkel',
#  'Make a Change': 'Buckwheat Zydeco',
#  'Could It Be I’m Falling in Love': 'The Spinners',
#  'Keep Going': 'The Revivalists',
#  'Good Times': 'Sam Cooke',
#  'All I Do': 'Stevie Wonder',
#  'Teardrops': 'Womack & Womack',
#  'The Weight': 'Aretha Franklin',
#  'All Summer Long': 'Kid Rock',
#  'Candle in the Wind': 'Elton John'}

# %%
# now it's time to put our API knowledge to use

# first, define your API key to authorize your request when using the API:
client_access_token = "zK66h3XvLu38c8sH0ZHu2DogDZJfBUyaE2dhuXGNhgoxbZWOjO7tNf2J9qedMbSv" # Replace with your token

# %%
# now, iterate through and get our lyrics URLs

url_dict = {}

for item in song_dict:
    song_title = item
    song_artist = song_dict[item]
        
    # Remember this is the URL for a search via the Genius API:
    genius_search_url = f'http://api.genius.com/search?q={song_title}&access_token={client_access_token}'

    # here's the API call
    resp = requests.get(genius_search_url)
    data = resp.json()
    
    # now search for match w/ artist 
    for song in data['response']['hits']:
        if song['result']['primary_artist']['name'] == song_artist:
            # if there's a match, get the url
            lyrics_url = song['result']['url']

            # add it to the url dict in format {song title, url}
            url_dict[song_title] = lyrics_url
            
            # just give a status update
            print("Matched artist: " + song_artist + " and title: " + song_title)
 
            # break out of for loop since we've got a match 
            break
            
url_dict
# Out:
# Matched artist: Aretha Franklin and title: Respect
# Matched artist: Dolly Parton and title: 9 to 5
# Matched artist: Ben E. King and title: Stand by Me
# Matched artist: Mary J. Blige and title: Work That
# Matched artist: Panic! at the Disco and title: High Hopes
# Matched artist: The O’Jays and title: Love Train
# Matched artist: Diana Ross and title: I’m Coming Out
# Matched artist: Funkadelic and title: One Nation Under a Groove
# Matched artist: Neil Young and title: Rocking in the Free World
# Matched artist: Lin-Manuel Miranda and title: My Shot
# Matched artist: Alicia Keys and title: Superwoman
# Matched artist: Lizzo and title: Good as Hell
# Matched artist: Stevie Wonder and title: Higher Ground
# Matched artist: Bill Withers and title: Lovely Day
# Matched artist: Beyoncé and title: Run the World (Girls)
# Matched artist: A Tribe Called Quest and title: Dis Generation
# Matched artist: Alicia Keys and title: Girl on Fire
# Matched artist: John Lennon and title: Power to the People
# Matched artist: Demi Lovato and title: Made in the USA
# Matched artist: Imagine Dragons and title: Believer
# Matched artist: Calle 13 and title: Latinoamérica
# Matched artist: Demi Lovato and title: Confident
# Matched artist: Whitney Houston and title: I Wanna Dance with Somebody (Who Loves Me)
# Matched artist: Lady Gaga and title: Born This Way
# Matched artist: Selena and title: Baila Esta Cumbia
# Matched artist: Village People and title: Macho Man
# Matched artist: The Clash and title: Clampdown
# Matched artist: Lady Gaga and title: The Edge of Glory
# Matched artist: Darius Rucker and title: Learn to Live
# Matched artist: Brad Paisley and title: Country Nation
# Matched artist: The Pointer Sisters and title: Yes We Can Can
# Matched artist: The Who and title: Baba O’Riley
# Matched artist: Beyoncé and title: Love on Top
# Matched artist: Christina Aguilera and title: Soar
# Matched artist: Gloria Estefan and title: Mi Tierra
# Matched artist: Lenny Kravitz and title: Let Love Rule
# Matched artist: Tracy Chapman and title: The Times They Are a-Changin’
# Matched artist: Fleetwood Mac and title: Never Going Back Again
# Matched artist: Curtis Mayfield and title: Move on Up
# Matched artist: The Avett Brothers and title: Ain’t No Man
# Matched artist: Willie Nelson and title: On the Road Again (Live)
# Matched artist: Muse and title: Uprising
# Matched artist: Steve Earle and title: The Revolution Starts...
# Matched artist: The Doobie Brothers and title: Takin’ It to the Streets
# Matched artist: David Bowie and title: Heroes
# Matched artist: Jackie Wilson and title: (Your Love Keeps Lifting Me) Higher & Higher
# Matched artist: Bleachers and title: Rollercoaster
# Matched artist: Lynyrd Skynyrd and title: Sweet Home Alabama
# Matched artist: Elton John and title: Tiny Dancer
# Matched artist: Survivor and title: Eye of the Tiger
# Matched artist: Tom Petty and the Heartbreakers and title: American Girl
# Matched artist: Ariana Grande and title: God Is a Woman
# Matched artist: Childish Gambino and title: Redbone
# Matched artist: E-40 and title: Choices (Yup)
# Matched artist: No Doubt and title: Just a Girl
# Matched artist: Otis Redding and title: Try a Little Tenderness
# Matched artist: Queen Latifah and title: Ladies First
# Matched artist: Sara Bareilles and title: King of Anything
# Matched artist: Selena and title: Bidi Bidi Bom Bom
# Matched artist: Beyoncé and title: Freedom (Homecoming Live)
# Matched artist: Bruce Springsteen and title: We Take Care of Our Own
# Matched artist: Janelle Monáe and title: Tightrope
# Matched artist: Johnny Cash and title: I’ve Been Everywhere
# Matched artist: Spoon and title: The Underdog
# Matched artist: The Modern Lovers and title: Roadrunner
# Matched artist: Shea Diamond and title: American Pie
# Matched artist: The Trammps and title: Disco Inferno
# Matched artist: Galantis and title: Runaway (U & I)
# Matched artist: The Spinners and title: Could It Be I’m Falling in Love
# Matched artist: The Revivalists and title: Keep Going
# Matched artist: Stevie Wonder and title: All I Do
# Matched artist: Womack & Womack and title: Teardrops
# Matched artist: Kid Rock and title: All Summer Long
# Matched artist: Elton John and title: Candle in the Wind
# {'Respect': 'https://genius.com/Aretha-franklin-respect-lyrics',
#  '9 to 5': 'https://genius.com/Dolly-parton-9-to-5-lyrics',
#  'Stand by Me': 'https://genius.com/Ben-e-king-stand-by-me-lyrics',
#  'Work That': 'https://genius.com/Mary-j-blige-work-that-lyrics',
#  'High Hopes': 'https://genius.com/Panic-at-the-disco-high-hopes-lyrics',
#  'Love Train': 'https://genius.com/The-ojays-love-train-lyrics',
#  'I’m Coming Out': 'https://genius.com/Diana-ross-im-coming-out-lyrics',
#  'One Nation Under a Groove': 'https://genius.com/Funkadelic-one-nation-under-a-groove-lyrics',
#  'Rocking in the Free World': 'https://genius.com/Neil-young-rockin-in-the-free-world-electric-lyrics',
#  'My Shot': 'https://genius.com/Lin-manuel-miranda-my-shot-demo-lyrics',
#  'Superwoman': 'https://genius.com/Alicia-keys-superwoman-lyrics',
#  'Good as Hell': 'https://genius.com/Lizzo-good-as-hell-lyrics',
#  'Higher Ground': 'https://genius.com/Stevie-wonder-higher-ground-lyrics',
#  'Lovely Day': 'https://genius.com/Bill-withers-lovely-day-lyrics',
#  'Run the World (Girls)': 'https://genius.com/Beyonce-run-the-world-girls-lyrics',
#  'Dis Generation': 'https://genius.com/A-tribe-called-quest-dis-generation-lyrics',
#  'Girl on Fire': 'https://genius.com/Alicia-keys-girl-on-fire-inferno-version-lyrics',
#  'Power to the People': 'https://genius.com/John-lennon-power-to-the-people-lyrics',
#  'Made in the USA': 'https://genius.com/Demi-lovato-made-in-the-usa-lyrics',
#  'Believer': 'https://genius.com/Imagine-dragons-believer-lyrics',
#  'Latinoamérica': 'https://genius.com/Calle-13-latinoamerica-lyrics',
#  'Confident': 'https://genius.com/Demi-lovato-confident-lyrics',
#  'I Wanna Dance with Somebody (Who Loves Me)': 'https://genius.com/Whitney-houston-i-wanna-dance-with-somebody-who-loves-me-lyrics',
#  'Born This Way': 'https://genius.com/Lady-gaga-born-this-way-lyrics',
#  'Baila Esta Cumbia': 'https://genius.com/Selena-baila-esta-cumbia-lyrics',
#  'Macho Man': 'https://genius.com/Village-people-macho-man-lyrics',
#  'Clampdown': 'https://genius.com/The-clash-clampdown-lyrics',
#  'The Edge of Glory': 'https://genius.com/Lady-gaga-the-edge-of-glory-lyrics',
#  'Learn to Live': 'https://genius.com/Darius-rucker-learn-to-live-lyrics',
#  'Country Nation': 'https://genius.com/Brad-paisley-country-nation-lyrics',
#  'Yes We Can Can': 'https://genius.com/The-pointer-sisters-yes-we-can-can-lyrics',
#  'Baba O’Riley': 'https://genius.com/The-who-baba-oriley-lyrics',
#  'Love on Top': 'https://genius.com/Beyonce-love-on-top-lyrics',
#  'Soar': 'https://genius.com/Christina-aguilera-soar-lyrics',
#  'Mi Tierra': 'https://genius.com/Gloria-estefan-mi-tierra-lyrics',
#  'Let Love Rule': 'https://genius.com/Lenny-kravitz-let-love-rule-lyrics',
#  'The Times They Are a-Changin’': 'https://genius.com/Tracy-chapman-the-times-they-are-a-changin-lyrics',
#  'Never Going Back Again': 'https://genius.com/Fleetwood-mac-never-going-back-again-lyrics',
#  'Move on Up': 'https://genius.com/Curtis-mayfield-move-on-up-lyrics',
#  'Ain’t No Man': 'https://genius.com/The-avett-brothers-aint-no-man-lyrics',
#  'On the Road Again (Live)': 'https://genius.com/Willie-nelson-on-the-road-again-live-2002-stars-and-guitars-lyrics',
#  'Uprising': 'https://genius.com/Muse-uprising-lyrics',
#  'The Revolution Starts...': 'https://genius.com/Steve-earle-the-revolution-starts-now-lyrics',
#  'Takin’ It to the Streets': 'https://genius.com/The-doobie-brothers-takin-it-to-the-streets-lyrics',
#  'Heroes ': 'https://genius.com/David-bowie-heroes-lyrics',
#  '(Your Love Keeps Lifting Me) Higher & Higher': 'https://genius.com/Jackie-wilson-your-love-keeps-lifting-me-higher-and-higher-lyrics',
#  'Rollercoaster': 'https://genius.com/Bleachers-rollercoaster-lyrics',
#  'Sweet Home Alabama': 'https://genius.com/Lynyrd-skynyrd-sweet-home-alabama-lyrics',
#  'Tiny Dancer': 'https://genius.com/Elton-john-tiny-dancer-lyrics',
#  'Eye of the Tiger': 'https://genius.com/Survivor-eye-of-the-tiger-lyrics',
#  'American Girl': 'https://genius.com/Tom-petty-and-the-heartbreakers-american-girl-lyrics',
#  'God Is a Woman': 'https://genius.com/Ariana-grande-god-is-a-woman-lyrics',
#  'Redbone': 'https://genius.com/Childish-gambino-redbone-lyrics',
#  'Choices (Yup)': 'https://genius.com/E-40-choices-yup-lyrics',
#  'Just a Girl': 'https://genius.com/No-doubt-just-a-girl-lyrics',
#  'Try a Little Tenderness': 'https://genius.com/Otis-redding-try-a-little-tenderness-lyrics',
#  'Ladies First': 'https://genius.com/Queen-latifah-ladies-first-lyrics',
#  'King of Anything': 'https://genius.com/Sara-bareilles-king-of-anything-lyrics',
#  'Bidi Bidi Bom Bom': 'https://genius.com/Selena-bidi-bidi-bom-bom-lyrics',
#  'Freedom (Homecoming Live)': 'https://genius.com/Beyonce-freedom-homecoming-live-lyrics',
#  'We Take Care of Our Own': 'https://genius.com/Bruce-springsteen-we-take-care-of-our-own-lyrics',
#  'Tightrope ': 'https://genius.com/Janelle-monae-tightrope-lyrics',
#  'I’ve Been Everywhere': 'https://genius.com/Johnny-cash-ive-been-everywhere-lyrics',
#  'The Underdog': 'https://genius.com/Spoon-the-underdog-lyrics',
#  'Roadrunner': 'https://genius.com/The-modern-lovers-roadrunner-lyrics',
#  'American Pie': 'https://genius.com/Shea-diamond-american-pie-lyrics',
#  'Disco Inferno ': 'https://genius.com/The-trammps-disco-inferno-lyrics',
#  'Runaway (U & I)': 'https://genius.com/Galantis-runaway-u-and-i-lyrics',
#  'Could It Be I’m Falling in Love': 'https://genius.com/The-spinners-could-it-be-im-falling-in-love-lyrics',
#  'Keep Going': 'https://genius.com/The-revivalists-keep-going-lyrics',
#  'All I Do': 'https://genius.com/Stevie-wonder-all-i-do-lyrics',
#  'Teardrops': 'https://genius.com/Womack-and-womack-teardrops-lyrics',
#  'All Summer Long': 'https://genius.com/Kid-rock-all-summer-long-lyrics',
#  'Candle in the Wind': 'https://genius.com/Elton-john-candle-in-the-wind-lyrics'}

# %%
# now we've got our URL dict so we can start scraping lyrics!

import re

for item in url_dict:
    song_title = item
    song_artist = song_dict[item]   # note that later in the semester, we'll learn
                                    # another method of storing multidimensional data
                                    # for now, though, we'll just keep these two dicts
    song_url = url_dict[item]  

    # get the contents of the lyrics page
    resp = requests.get(song_url) 
    html_str = resp.text

    # turn it into a BS object and get the lyrics div
    document = BeautifulSoup(html_str, "html.parser")
    lyrics = document.find('p').text
    
    # let's do some quick cleaning 
    cleaner_lyrics = re.sub("\[.*\]\n", "", lyrics) # remove square brackets and contents
    cleanest_lyrics = re.sub("^[\n]{3}","", cleaner_lyrics) # remove the three opening newlines

    # store it in a file

    # we'll use the final part of the URL as a filename 
    print(song_url)
    filename = song_url.replace("https://genius.com/","")
    print(filename)
    filename = filename.replace("-lyrics","") + ".txt"
    print(filename)
    
    # store the lyrics in a subdir called "lyrics"; 
    path = "lyrics/" + filename
    
    # IMPORTANT: "lyrics" dir needs to exist first, otherwise it will break  
    # you need to go to the directory on your computer that holds  
    # this Jupyter notebook (class8-lyrics-scraping-inclass-ds) and create a new folder called 'lyrics'
    
    with open(path, "w") as file:
        file.writelines(cleanest_lyrics)
        print("Wrote lyrics to: " + filename)
# Out:
# https://genius.com/Aretha-franklin-respect-lyrics
# Aretha-franklin-respect-lyrics
# Aretha-franklin-respect.txt
# Wrote lyrics to: Aretha-franklin-respect.txt
# https://genius.com/Dolly-parton-9-to-5-lyrics
# Dolly-parton-9-to-5-lyrics
# Dolly-parton-9-to-5.txt
# Wrote lyrics to: Dolly-parton-9-to-5.txt
# https://genius.com/Ben-e-king-stand-by-me-lyrics
# Ben-e-king-stand-by-me-lyrics
# Ben-e-king-stand-by-me.txt
# Wrote lyrics to: Ben-e-king-stand-by-me.txt
# https://genius.com/Mary-j-blige-work-that-lyrics
# Mary-j-blige-work-that-lyrics
# Mary-j-blige-work-that.txt
# Wrote lyrics to: Mary-j-blige-work-that.txt
# https://genius.com/Panic-at-the-disco-high-hopes-lyrics
# Panic-at-the-disco-high-hopes-lyrics
# Panic-at-the-disco-high-hopes.txt
# Wrote lyrics to: Panic-at-the-disco-high-hopes.txt
# https://genius.com/The-ojays-love-train-lyrics
# The-ojays-love-train-lyrics
# The-ojays-love-train.txt
# Wrote lyrics to: The-ojays-love-train.txt
# https://genius.com/Diana-ross-im-coming-out-lyrics
# Diana-ross-im-coming-out-lyrics
# Diana-ross-im-coming-out.txt
# Wrote lyrics to: Diana-ross-im-coming-out.txt
# https://genius.com/Funkadelic-one-nation-under-a-groove-lyrics
# Funkadelic-one-nation-under-a-groove-lyrics
# Funkadelic-one-nation-under-a-groove.txt
# Wrote lyrics to: Funkadelic-one-nation-under-a-groove.txt
# https://genius.com/Neil-young-rockin-in-the-free-world-electric-lyrics
# Neil-young-rockin-in-the-free-world-electric-lyrics
# Neil-young-rockin-in-the-free-world-electric.txt
# Wrote lyrics to: Neil-young-rockin-in-the-free-world-electric.txt
# https://genius.com/Lin-manuel-miranda-my-shot-demo-lyrics
# Lin-manuel-miranda-my-shot-demo-lyrics
# Lin-manuel-miranda-my-shot-demo.txt
# Wrote lyrics to: Lin-manuel-miranda-my-shot-demo.txt
# https://genius.com/Alicia-keys-superwoman-lyrics
# Alicia-keys-superwoman-lyrics
# Alicia-keys-superwoman.txt
# Wrote lyrics to: Alicia-keys-superwoman.txt
# https://genius.com/Lizzo-good-as-hell-lyrics
# Lizzo-good-as-hell-lyrics
# Lizzo-good-as-hell.txt
# Wrote lyrics to: Lizzo-good-as-hell.txt
# https://genius.com/Stevie-wonder-higher-ground-lyrics
# Stevie-wonder-higher-ground-lyrics
