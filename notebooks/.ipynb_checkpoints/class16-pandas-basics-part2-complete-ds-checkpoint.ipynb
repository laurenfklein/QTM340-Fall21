# %% [markdown]
# # Pandas Basics — Part 2

# %% [markdown]
# _I adapted this notebook from Melanie Walsh's [Pandas Basics — Part 2](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Data-Analysis/Pandas-Basics-Part2.html), which is from her online textbook [Introduction to Cultural Analytics & Python](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/welcome.html)_

# %% [markdown]
# In this lesson, we're going to introduce some more fundamentals of [pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html), a powerful Python library for working with tabular data like CSV files.
#
# We will review skills learned from the last lesson and introduce how to:
#
# * Broadly examine data
# * Work with missing data
# * Rename, drop, and add new columns
# * Perform mathematical calculations
# * Aggregate subsets of data
# * Make a simple time series

# %% [markdown]
# ## Dataset
# ### The Trans-Atlantic Slave Trade Database

# %% [markdown]
# ```{epigraph}
# [D]isplaying data alone could not and did not offer the atonement descendants of slaves
# sought or capture the inhumanity of this archive’s formation.
# ```
# -- Jessica Marie Johnson, <a href="https://read.dukeupress.edu/social-text/article/36/4%20(137)/57/137032/Markup-BodiesBlack-Life-Studies-and-Slavery-Death">“Markup Bodies”</a>

# %% [markdown]
# The dataset that we're going to be working with in this lesson is taken from [The Trans-Atlantic Slave Trade Database](https://www.slavevoyages.org/voyage/database), part of the [*Slave Voyages* project](https://www.slavevoyages.org/). The larger database includes information about 35,000 slave-trading voyages from 1514-1866. The dataset we're working with here was filtered to include the 30,000 voyages that landed in the Americas and the Caribbean. The data was filtered to also include the percentage of enslaved men, women, and children on the voyages.

# %% [markdown]
# We're working with this data for a number of reasons. The *Slave Voyages* project is a major data-driven contribution to the history of slavery and to the field of the digital humanities. Before the Trans-Atlantic Slave Trade Database, as DH scholar Jessica Johnson [writes,](https://read.dukeupress.edu/social-text/article-abstract/36/4%20(137)/57/137032/Markup-BodiesBlack-Life-Studies-and-Slavery-Death?redirectedFrom=fulltext) "historians assumed enslaved women and children played a negligible role in the slave trade." But evidence from the Trans-Atlantic Slave Trade Database suggested otherwise. "The existence of the Trans-Atlantic Slave Trade Database immediately reshaped debates about numbers of women and children exported from the continent," Johnson says, "influencing work on women in the slave trade on the African coast, slavery in African societies, and women in the slave trade to the Americas."
#
# Though the Trans-Atlantic Slave Trade Database helped shed new light on the roles of enslaved women and children, Johnson makes clear that it was not computation or data alone that shed this light:
# > [D]isplaying data alone could not and did not offer the atonement descendants of slaves sought or capture the inhumanity of this archive’s formation. Culling the lives of women and children from the data set required approaching the data with intention. It required a methodology attuned to black life and to dismantling the methods used to create the manifests in the first place, then designing and launching an interface responsive to the desire of descendants of slaves for reparation and redress.
#
# In this spirit, we want to think about how responsible data analysis requires more than just data and technical tools like pandas. It requires approaching data with intention and developing methodologies geared toward justice. This is especially necessary when dealing with data that records and perpetrates violence like the Trans-Atlantic Slave Trade Database.

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# To use the Pandas library, we first need to `import` it.

# %%
import pandas as pd

# %% [markdown]
# The above `import` statement not only imports the pandas library but also gives it an alias or nickname — `pd`. This alias will save us from having to type out the entire words `pandas` each time we need to use it. Many Python libraries have commonly used aliases like `pd`.

# %% [markdown]
# ## Set Display Settings

# %% [markdown]
# By default, pandas will display 60 rows and 20 columns. I often change [Pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# ## Read in CSV File

# %% [markdown]
# To read in a CSV file, we will use the function `pd.read_csv()` and insert the name of our desired file path.

# %%
slave_voyages_df = pd.read_csv('../docs/Trans-Atlantic-Slave-Trade_Americas.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# This creates a pandas [DataFrame object](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#DataFrame) — often abbreviated as *df*, e.g., *slave_voyages_df*. A DataFrame looks and acts a lot like a spreadsheet. But it has special powers and functions that we will discuss in the next few lessons.

# %% [markdown]
# When reading in the CSV file, we also specified the `encoding` and `delimiter`. The `delimiter` specifies the character that separates or "delimits" the columns in our dataset. For CSV files, the delimiter will most often be a comma. (CSV is short for *Comma Separated Values*.) Sometimes, however, the delimiter of a CSV file might be a tab (`/t`) or, more rarely, another character.

# %% [markdown]
# ## Display Data

# %% [markdown]
# We can display a DataFrame in a Jupyter notebook simply by running a cell with the variable name of the DataFrame.

# %% [markdown]
# `NaN` is the Pandas value for any missing data. See ["Working with missing data"](https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html?highlight=nan) for more information

# %%
slave_voyages_df
# Out:
#        Voyage ID       Vessel name Voyage ship place where vessel registered   \
# 0              1   Pastora de Lima                                        NaN
# 1              2           Tibério                                        NaN
# 2              3      Paquete Real                                        NaN
# 3              4       Bom Caminho                                        NaN
# 4              5        Benigretta                                        NaN
# ...          ...               ...                                        ...
# 30442     900232         Tourville                                        NaN
# 30443     900233      General Rêgo                                        NaN
# 30444     900234  Duas Clementinas                                        NaN
# 30445     900236        Rio Tâmega                                        NaN
# 30446     900237              Rosa                                        NaN
#
#       Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                         Rio de Janeiro
# 1                                Bahia, port unspecified
# 2                                Bahia, port unspecified
# 3                                Bahia, port unspecified
# 4                                Bahia, port unspecified
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                 Southeast Brazil, port unspecified
# 30444                                     Rio de Janeiro
# 30445                 Southeast Brazil, port unspecified
# 30446                                     Rio de Janeiro
#
#       Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                             Mozambique
# 1                                             Mozambique
# 2                                                Cabinda
# 3                                              Quilimane
# 4                                                Cabinda
# ...                                                  ...
# 30442  West Central Africa and St. Helena, port unspe...
# 30443                                           Benguela
# 30444                                           Benguela
# 30445                                           Benguela
# 30446                                           Benguela
#
#       Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                                Bahia, port unspecified
# 1                                Bahia, port unspecified
# 2                                Bahia, port unspecified
# 3                                Bahia, port unspecified
# 4                                Bahia, port unspecified
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                                     Rio de Janeiro
# 30444                                     Rio de Janeiro
# 30445                                     Rio de Janeiro
# 30446                                     Rio de Janeiro
#
#        Total embarked  Year of arrival at port of disembarkation  \
# 0                 NaN                                       1817
# 1                 NaN                                       1817
# 2                 NaN                                       1817
# 3                 NaN                                       1817
# 4                 NaN                                       1817
# ...               ...                                        ...
# 30442             NaN                                       1848
# 30443             NaN                                       1849
# 30444             NaN                                       1850
# 30445             NaN                                       1851
# 30446             NaN                                       1851
#
#        Slaves arrived at 1st port  Percent men  Percent women  \
# 0                           290.0          NaN            NaN
# 1                           223.0          NaN            NaN
# 2                           350.0          NaN            NaN
# 3                           342.0          NaN            NaN
# 4                           516.0          NaN            NaN
# ...                           ...          ...            ...
# 30442                         NaN          NaN            NaN
# 30443                         NaN          NaN            NaN
# 30444                         NaN          NaN            NaN
# 30445                         NaN          NaN            NaN
# 30446                         NaN          NaN            NaN
#
#        Percent children  Mortality rate             Captain's name  \
# 0                   NaN            0.28          Dias, Manoel José
# 1                   NaN             NaN        Mata, José Maria da
# 2                   NaN            0.14  Ferreira, José dos Santos
# 3                   NaN            0.10   Dias, Domingos Francisco
# 4                   NaN             NaN                        NaN
# ...                 ...             ...                        ...
# 30442               NaN             NaN                       Alex
# 30443               NaN             NaN                        NaN
# 30444               NaN             NaN                        NaN
# 30445               NaN             NaN                        NaN
# 30446               NaN             NaN                        NaN
#
#       Resistance label
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 30442              NaN
# 30443              NaN
# 30444              NaN
# 30445              NaN
# 30446              NaN
#
# [30447 rows x 15 columns]

# %% [markdown]
# There are a few important things to note about the DataFrame displayed here:
#
# * Index
#     * The ascending numbers in the very left-hand column of the DataFrame is called the pandas *Index*. You can select rows based on the Index.
#     * By default, the Index is a sequence of numbers starting with zero. However, you can change the Index to something else, such as one of the columns in your dataset.
#
# * Truncation
#     * The DataFrame is truncated, signaled by the ellipses in the middle `...` of every column.
#     * The DataFrame is truncated because we set our default display settings to 100 rows. Anything more than 100 rows will be truncated. To display all the rows, we would need to alter pandas' default display settings yet again.
#
# * Rows x Columns
#     * Pandas reports how many rows and columns are in this dataset at the bottom of the output (30,447 x 15 columns).

# %% [markdown]
# ## Display First *n* Rows
#
# To look at the first *n* rows in a DataFrame, we can use a method called `.head()`.

# %%
slave_voyages_df.head(10)
# Out:
#    Voyage ID         Vessel name Voyage ship place where vessel registered   \
# 0          1     Pastora de Lima                                        NaN
# 1          2             Tibério                                        NaN
# 2          3        Paquete Real                                        NaN
# 3          4         Bom Caminho                                        NaN
# 4          5          Benigretta                                        NaN
# 5          6              Voador                                        NaN
# 6          7             Formiga                                        NaN
# 7          8  Vigilante Africano                                        NaN
# 8          9           Constante                                        NaN
# 9         10         Comerciante                                        NaN
#
#   Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                     Rio de Janeiro
# 1                            Bahia, port unspecified
# 2                            Bahia, port unspecified
# 3                            Bahia, port unspecified
# 4                            Bahia, port unspecified
# 5                            Bahia, port unspecified
# 6                            Bahia, port unspecified
# 7                       Pernambuco, port unspecified
# 8                            Bahia, port unspecified
# 9                            Bahia, port unspecified
#
#   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                         Mozambique
# 1                                         Mozambique
# 2                                            Cabinda
# 3                                          Quilimane
# 4                                            Cabinda
# 5                                         Mozambique
# 6                                            Malembo
# 7                                             Luanda
# 8                                            Cabinda
# 9                                            Cabinda
#
#   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                            Bahia, port unspecified
# 1                            Bahia, port unspecified
# 2                            Bahia, port unspecified
# 3                            Bahia, port unspecified
# 4                            Bahia, port unspecified
# 5                            Bahia, port unspecified
# 6                            Bahia, port unspecified
# 7                            Bahia, port unspecified
# 8                            Bahia, port unspecified
# 9                            Bahia, port unspecified
#
#    Total embarked  Year of arrival at port of disembarkation  \
# 0             NaN                                       1817
# 1             NaN                                       1817
# 2             NaN                                       1817
# 3             NaN                                       1817
# 4             NaN                                       1817
# 5             NaN                                       1817
# 6             NaN                                       1817
# 7             NaN                                       1817
# 8             NaN                                       1817
# 9             NaN                                       1817
#
#    Slaves arrived at 1st port  Percent men  Percent women  Percent children  \
# 0                       290.0          NaN            NaN               NaN
# 1                       223.0          NaN            NaN               NaN
# 2                       350.0          NaN            NaN               NaN
# 3                       342.0          NaN            NaN               NaN
# 4                       516.0          NaN            NaN               NaN
# 5                       515.0          NaN            NaN               NaN
# 6                       204.0          NaN            NaN               NaN
# 7                       374.0          NaN            NaN               NaN
# 8                       345.0          NaN            NaN               NaN
# 9                       478.0          NaN            NaN               NaN
#
#    Mortality rate             Captain's name Resistance label
# 0        0.280000          Dias, Manoel José              NaN
# 1             NaN        Mata, José Maria da              NaN
# 2        0.140000  Ferreira, José dos Santos              NaN
# 3        0.100000   Dias, Domingos Francisco              NaN
# 4             NaN                        NaN              NaN
# 5             NaN                        NaN              NaN
# 6             NaN     Viana, Isidoro Antônio              NaN
# 7             NaN      Amorim, José Gomes de              NaN
# 8        0.060000           Narciso, Antônio              NaN
# 9        0.006237     Braga, Isidoro Martins              NaN

# %% [markdown]
# ## Examine Data

# %% [markdown]
# ### Shape

# %% [markdown]
# To explicitly check for how many rows vs columns make up a dataset, we can use the `.shape` method.

# %%
slave_voyages_df.shape
# Out:
# (30447, 15)

# %% [markdown]
# There are 30,447 rows and 15 columns.

# %% [markdown]
# ### Data Types

# %% [markdown]
# Just like Python has different data types, Pandas has different data types, too. These data types are automatically assigned to columns when we read in a CSV file. We can check these Pandas data types with the [`.dtypes` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html).

# %% [markdown]
# | **Pandas Data Type** |  **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `object`         | string                                                                               |
# | `float64`         | float                                               |
# | `int64`       | integer                                                        |
# | `datetime64`       |  date time

# %%
slave_voyages_df.dtypes
# Out:
# Voyage ID                                                                              int64
# Vessel name                                                                           object
# Voyage ship place where vessel registered                                             object
# Voyage itinerary imputed port where began (ptdepimp) place                            object
# Voyage itinerary imputed principal place of slave purchase (mjbyptimp)                object
# Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place     object
# Total embarked                                                                       float64
# Year of arrival at port of disembarkation                                              int64
# Slaves arrived at 1st port                                                           float64
# Percent men                                                                          float64
# Percent women                                                                        float64
# Percent children                                                                     float64
# Mortality rate                                                                       float64
# Captain's name                                                                        object
# Resistance label                                                                      object
# dtype: object

# %% [markdown]
# It's important to always check the data types in your DataFrame. For example, sometimes numeric values will accidentally be interpreted as a string object. To perform calculations on this data, you would need to first convert that column from a string to an integer.

# %% [markdown]
# ### Columns

# %% [markdown]
# We can also check the column names of the DataFrame with [`.columns`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html)

# %%
slave_voyages_df.columns
# Out:
# Index(['Voyage ID', 'Vessel name',
#        'Voyage ship place where vessel registered ',
#        'Voyage itinerary imputed port where began (ptdepimp) place',
#        'Voyage itinerary imputed principal place of slave purchase (mjbyptimp) ',
#        'Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place',
#        'Total embarked', 'Year of arrival at port of disembarkation',
#        'Slaves arrived at 1st port', 'Percent men', 'Percent women',
#        'Percent children', 'Mortality rate', 'Captain's name',
#        'Resistance label'],
#       dtype='object')

# %% [markdown]
# ### Summary Statistics

# %%
slave_voyages_df.describe(include='all')
# Out:
#             Voyage ID Vessel name Voyage ship place where vessel registered   \
# count    30447.000000       30447                                       6654
# unique            NaN        8119                                        134
# top               NaN                                              Liverpool
# freq              NaN        1071                                       3016
# mean     43748.167077         NaN                                        NaN
# std      71791.702575         NaN                                        NaN
# min          1.000000         NaN                                        NaN
# 25%      16613.500000         NaN                                        NaN
# 50%      32768.000000         NaN                                        NaN
# 75%      50858.500000         NaN                                        NaN
# max     900237.000000         NaN                                        NaN
#
#        Voyage itinerary imputed port where began (ptdepimp) place  \
# count                                               26971
# unique                                                200
# top                                             Liverpool
# freq                                                 4441
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# count                                               30369
# unique                                                167
# top                             Africa., port unspecified
# freq                                                 6414
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# count                                               30447
# unique                                                230
# top                               Bahia, port unspecified
# freq                                                 4223
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Total embarked  Year of arrival at port of disembarkation  \
# count      7429.000000                               30447.000000
# unique             NaN                                        NaN
# top                NaN                                        NaN
# freq               NaN                                        NaN
# mean        340.205950                                1762.279765
# std         176.729658                                  58.052020
# min           1.000000                                1520.000000
# 25%         204.000000                                1731.000000
# 50%         333.000000                                1771.000000
# 75%         455.000000                                1804.000000
# max        1500.000000                                1866.000000
#
#         Slaves arrived at 1st port  Percent men  Percent women  \
# count                 17634.000000  3066.000000    3066.000000
# unique                         NaN          NaN            NaN
# top                            NaN          NaN            NaN
# freq                           NaN          NaN            NaN
# mean                    277.974878     0.497521       0.273172
# std                     158.132355     0.143490       0.118078
# min                       1.000000     0.000000       0.000000
# 25%                     160.000000     0.405033       0.194860
# 50%                     256.000000     0.497505       0.264230
# 75%                     372.750000     0.588240       0.345807
# max                    1700.000000     1.000000       1.000000
#
#         Percent children  Mortality rate Captain's name    Resistance label
# count        3800.000000     6006.000000          27397                 380
# unique               NaN             NaN          16258                   6
# top                  NaN             NaN    Smith, John  Slave insurrection
# freq                 NaN             NaN             36                 336
# mean            0.197883        0.119959            NaN                 NaN
# std             0.156541        0.141486            NaN                 NaN
# min             0.000000        0.000000            NaN                 NaN
# 25%             0.063940        0.030000            NaN                 NaN
# 50%             0.177285        0.070000            NaN                 NaN
# 75%             0.295239        0.160000            NaN                 NaN
# max             1.000000        1.000000            NaN                 NaN

# %% [markdown]
# ## Missing Data

# %% [markdown]
# ```{epigraph}
# The conceit of the archive is that it is the repository of answers, of knowable conclusions, of the data needed to explain or understand the past.
#
# The reality, however, is that the archive is the troubled genesis of our always-failed effort to unravel the effects of the past on the present; rather than verifiable truths, the archive — and its silences — house the very questions that unsettle us.
# ```
# -- Jennifer Morgan, ["Accounting for 'The Most Excruciating Torment'"](https://read.dukeupress.edu/history-of-the-present/article-abstract/6/2/184/153282/Accounting-for-The-Most-Excruciating-Torment?redirectedFrom=PDF)

# %% [markdown]
# Responsible data analysis requires understanding missing data. The Trans-Atlantic Slave Trade Database, as historian Jennifer Morgan [writes](https://read.dukeupress.edu/history-of-the-present/article-abstract/6/2/184/153282/Accounting-for-The-Most-Excruciating-Torment?redirectedFrom=PDF), contains innumerable "silences" and "gaps." These silences include the thoughts, feelings, and experiences of the enslaved African people on board the voyages — silences that cannot be found in the database itself.
#
# There are other kinds of silences and gaps that can be detected in the database itself, however. For example, while some of the voyages in the the Trans-Atlantic Slave Trade Database recorded information about how many enslaved women and children were aboard, most did not. Yet focusing on the data that is there and analyzing trends in the missing data can help shed light on the history of gender and enslavement. The fact that most ship captains did not record gender information, Morgan argues, helps tells us about their "priorities": "[W]e can assume that had it been financially significant to have more men than women that data would have been more scrupulously recorded."

# %% [markdown]
# ### .isna() / .notna()

# %% [markdown]
# Pandas has special ways of dealing with missing data. As you may have already noticed, blank rows in a CSV file show up as `NaN` in a Pandas DataFrame.

# %% [markdown]
# To filter and count the number of missing/not missing values in a dataset, we can use the special `.isna()` and `.notna()` methods on a DataFrame or Series object.

# %%
slave_voyages_df['Percent women'].notna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30442    False
# 30443    False
# 30444    False
# 30445    False
# 30446    False
# Name: Percent women, Length: 30447, dtype: bool

# %% [markdown]
# The `.isna()` and `.notna()` methods return True/False pairs for each row, which we can use to filter the DataFrame for any rows that have information in a given column. For example, we can filter the DataFrame for only rows that have information about the percentage of enslaved women aboard the voyage.

# %%
slave_voyages_df[slave_voyages_df['Percent women'].notna()]
# Out:
#        Voyage ID       Vessel name Voyage ship place where vessel registered   \
# 502          506           Vulcano                                        NaN
# 550          554      Deux Nantais                                        NaN
# 557          561   Nuevo Campeador                                        NaN
# 658          664            Xerxes                                        NaN
# 662          668         Intrepido                                        NaN
# ...          ...               ...                                        ...
# 30144      96040  Príncipe Regente                                        NaN
# 30162      96069        Constância                                        NaN
# 30166      96073  Marques de Flori                                        NaN
# 30178      96085          Catalina                                        NaN
# 30192      96099             S Ana                                        NaN
#
#       Voyage itinerary imputed port where began (ptdepimp) place  \
# 502                                       Rio de Janeiro
# 550                                               Nantes
# 557                                     Santiago de Cuba
# 658                                               Havana
# 662                                               Havana
# ...                                                  ...
# 30144                                            Setubal
# 30162                                             Havana
# 30166                                                NaN
# 30178                                                NaN
# 30192                                                NaN
#
#       Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 502                                            Quilimane
# 550                                              Sherbro
# 557                                              Calabar
# 658                                                Bonny
# 662                                                Bonny
# ...                                                  ...
# 30144                                        Saint-Louis
# 30162                                         Mozambique
# 30166                          Mauritius (Ile de France)
# 30178                          Africa., port unspecified
# 30192                          Africa., port unspecified
#
#       Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 502                                       Rio de Janeiro
# 550                                     Santiago de Cuba
# 557                               Cuba, port unspecified
# 658                               Cuba, port unspecified
# 662                               Cuba, port unspecified
# ...                                                  ...
# 30144                                         Montevideo
# 30162                                             Havana
# 30166                                         Montevideo
# 30178                                       Buenos Aires
# 30192                                       Buenos Aires
#
#        Total embarked  Year of arrival at port of disembarkation  \
# 502             568.0                                       1825
# 550             483.0                                       1824
# 557             303.0                                       1826
# 658             429.0                                       1828
# 662             343.0                                       1828
# ...               ...                                        ...
# 30144           107.0                                       1804
# 30162             NaN                                       1803
# 30166             NaN                                       1782
# 30178             NaN                                       1802
# 30192           160.0                                       1804
#
#        Slaves arrived at 1st port  Percent men  Percent women  \
# 502                         504.0      0.35305        0.12595
# 550                         460.0      0.27511        0.11354
# 557                         263.0      0.60305        0.20229
# 658                         403.0      0.57357        0.12469
# 662                         168.0      0.27976        0.25595
# ...                           ...          ...            ...
# 30144                        80.0      0.60417        0.12500
# 30162                       101.0      0.43564        0.07921
# 30166                        40.0      0.85000        0.15000
# 30178                       237.0      0.77637        0.21941
# 30192                        81.0      0.31667        0.63333
#
#        Percent children  Mortality rate                       Captain's name  \
# 502             0.52099            0.11               Ferreira, Antônio José
# 550             0.61304            0.05                   Pelletier, Charles
# 557             0.19466            0.13                             Botel, J
# 658             0.30175            0.06                        Rebel, Felipe
# 662             0.46429            0.61                    Puig y Miro, Jozé
# ...                 ...             ...                                  ...
# 30144           0.27083            0.25  Paula Rodríguez, Francisco de Paula
# 30162           0.48515             NaN                                Rossi
# 30166           0.00000             NaN                     Moulin, François
# 30178           0.00422             NaN                                  NaN
# 30192           0.05000            0.49         Amaro, Rodriguez de Oliveira
#
#       Resistance label
# 502                NaN
# 550                NaN
# 557                NaN
# 658                NaN
# 662                NaN
# ...                ...
# 30144              NaN
# 30162              NaN
# 30166              NaN
# 30178              NaN
# 30192              NaN
#
# [3066 rows x 15 columns]

# %% [markdown]
# The data is now filtered to only include the 3066 rows with information about how many women were aboard the voyage.
#
# To explicitly count the number of blank rows, we can use the `.value_counts()` method.

# %%
slave_voyages_df['Percent women'].isna().value_counts()
# Out:
# True     27381
# False     3066
# Name: Percent women, dtype: int64

# %% [markdown]
# There are 27,381 that do not contain information about the number of enslaved women on the voyage (`isna` = True) and 3066 rows that do contain this information (`isna` = False).

# %% [markdown]
# To quickly transform these numbers into percentages, we can set the `normalize=` parameter to True.

# %%
slave_voyages_df['Percent women'].isna().value_counts(normalize=True)
# Out:
# True     0.8993
# False    0.1007
# Name: Percent women, dtype: float64

# %% [markdown]
# About 90% of rows in this dataset have information about the number of enslaved women on the voyage while 10% do not.

# %% [markdown]
# ### .count()

# %% [markdown]
# Because the `.count()` method always excludes NaN values, we can also count the number of values in each column and divide by the total number of rows in each column (`len()`) to find the percentage of not blank data in every column.

# %%
slave_voyages_df.count() / len(slave_voyages_df)
# Out:
# Voyage ID                                                                            1.000000
# Vessel name                                                                          1.000000
# Voyage ship place where vessel registered                                            0.218544
# Voyage itinerary imputed port where began (ptdepimp) place                           0.885834
# Voyage itinerary imputed principal place of slave purchase (mjbyptimp)               0.997438
# Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place    1.000000
# Total embarked                                                                       0.243998
# Year of arrival at port of disembarkation                                            1.000000
# Slaves arrived at 1st port                                                           0.579170
# Percent men                                                                          0.100700
# Percent women                                                                        0.100700
# Percent children                                                                     0.124807
# Mortality rate                                                                       0.197261
# Captain's name                                                                       0.899826
# Resistance label                                                                     0.012481
# dtype: float64

# %% [markdown]
# For example, 100% of the rows in the columns "year_of_arrival" contain information, while 1% of the rows in the column "Resistance label" contain information. The "Resistance label" indicates whether there is a record of the enslaved Africans aboard the voyage staging some form of resistance.

# %% [markdown]
# ### .fillna()

# %% [markdown]
# If we wanted, we could fill the `NaN` values in the DataFrame with a different value by using the `.fillna()` method.

# %%
slave_voyages_df['Percent women'].fillna('no gender information recorded')
# Out:
# 0        no gender information recorded
# 1        no gender information recorded
# 2        no gender information recorded
# 3        no gender information recorded
# 4        no gender information recorded
#                       ...
# 30442    no gender information recorded
# 30443    no gender information recorded
# 30444    no gender information recorded
# 30445    no gender information recorded
# 30446    no gender information recorded
# Name: Percent women, Length: 30447, dtype: object

# %% [markdown]
# ## Rename Columns

# %% [markdown]
# We can rename columns with the [`.rename()` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html) and the `columns=` parameter. For example, we can rename the "Resistance label" column "African resistance"

# %%
slave_voyages_df.rename(columns={'Resistance label': 'African resistance'})
# Out:
#        Voyage ID       Vessel name Voyage ship place where vessel registered   \
# 0              1   Pastora de Lima                                        NaN
# 1              2           Tibério                                        NaN
# 2              3      Paquete Real                                        NaN
# 3              4       Bom Caminho                                        NaN
# 4              5        Benigretta                                        NaN
# ...          ...               ...                                        ...
# 30442     900232         Tourville                                        NaN
# 30443     900233      General Rêgo                                        NaN
# 30444     900234  Duas Clementinas                                        NaN
# 30445     900236        Rio Tâmega                                        NaN
# 30446     900237              Rosa                                        NaN
#
#       Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                         Rio de Janeiro
# 1                                Bahia, port unspecified
# 2                                Bahia, port unspecified
# 3                                Bahia, port unspecified
# 4                                Bahia, port unspecified
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                 Southeast Brazil, port unspecified
# 30444                                     Rio de Janeiro
# 30445                 Southeast Brazil, port unspecified
# 30446                                     Rio de Janeiro
#
#       Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                             Mozambique
# 1                                             Mozambique
# 2                                                Cabinda
# 3                                              Quilimane
# 4                                                Cabinda
# ...                                                  ...
# 30442  West Central Africa and St. Helena, port unspe...
# 30443                                           Benguela
# 30444                                           Benguela
# 30445                                           Benguela
# 30446                                           Benguela
#
#       Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                                Bahia, port unspecified
# 1                                Bahia, port unspecified
# 2                                Bahia, port unspecified
# 3                                Bahia, port unspecified
# 4                                Bahia, port unspecified
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                                     Rio de Janeiro
# 30444                                     Rio de Janeiro
# 30445                                     Rio de Janeiro
# 30446                                     Rio de Janeiro
#
#        Total embarked  Year of arrival at port of disembarkation  \
# 0                 NaN                                       1817
# 1                 NaN                                       1817
# 2                 NaN                                       1817
# 3                 NaN                                       1817
# 4                 NaN                                       1817
# ...               ...                                        ...
# 30442             NaN                                       1848
# 30443             NaN                                       1849
# 30444             NaN                                       1850
# 30445             NaN                                       1851
# 30446             NaN                                       1851
#
#        Slaves arrived at 1st port  Percent men  Percent women  \
# 0                           290.0          NaN            NaN
# 1                           223.0          NaN            NaN
# 2                           350.0          NaN            NaN
# 3                           342.0          NaN            NaN
# 4                           516.0          NaN            NaN
# ...                           ...          ...            ...
# 30442                         NaN          NaN            NaN
# 30443                         NaN          NaN            NaN
# 30444                         NaN          NaN            NaN
# 30445                         NaN          NaN            NaN
# 30446                         NaN          NaN            NaN
#
#        Percent children  Mortality rate             Captain's name  \
# 0                   NaN            0.28          Dias, Manoel José
# 1                   NaN             NaN        Mata, José Maria da
# 2                   NaN            0.14  Ferreira, José dos Santos
# 3                   NaN            0.10   Dias, Domingos Francisco
# 4                   NaN             NaN                        NaN
# ...                 ...             ...                        ...
# 30442               NaN             NaN                       Alex
# 30443               NaN             NaN                        NaN
# 30444               NaN             NaN                        NaN
# 30445               NaN             NaN                        NaN
# 30446               NaN             NaN                        NaN
#
#       African resistance
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 30442                NaN
# 30443                NaN
# 30444                NaN
# 30445                NaN
# 30446                NaN
#
# [30447 rows x 15 columns]

# %% [markdown]
# Renaming the "Resistance label" column as above will only momentarily change that column's name, however. If we display our DataFrame, we will see that the column name has *not* changed permamently.

# %%
slave_voyages_df.head(1)
# Out:
#    Voyage ID      Vessel name Voyage ship place where vessel registered   \
# 0          1  Pastora de Lima                                        NaN
#
#   Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                     Rio de Janeiro
#
#   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                         Mozambique
#
#   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                            Bahia, port unspecified
#
#    Total embarked  Year of arrival at port of disembarkation  \
# 0             NaN                                       1817
#
#    Slaves arrived at 1st port  Percent men  Percent women  Percent children  \
# 0                       290.0          NaN            NaN               NaN
#
#    Mortality rate     Captain's name Resistance label
# 0            0.28  Dias, Manoel José              NaN

# %% [markdown]
# To save changes in the DataFrame, we need to reassign the DataFrame to the same variable.

# %%
slave_voyages_df = slave_voyages_df.rename(columns={'Resistance label': 'African resistance'})

# %%
slave_voyages_df.head(1)
# Out:
#    Voyage ID      Vessel name Voyage ship place where vessel registered   \
# 0          1  Pastora de Lima                                        NaN
#
#   Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                     Rio de Janeiro
#
#   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                         Mozambique
#
#   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                            Bahia, port unspecified
#
#    Total embarked  Year of arrival at port of disembarkation  \
# 0             NaN                                       1817
#
#    Slaves arrived at 1st port  Percent men  Percent women  Percent children  \
# 0                       290.0          NaN            NaN               NaN
#
#    Mortality rate     Captain's name African resistance
# 0            0.28  Dias, Manoel José                NaN

# %% [markdown]
# ## Drop Columns

# %% [markdown]
# We can remove a column from the DataFrame with the `.drop()` method and the column name.

# %%
slave_voyages_df = slave_voyages_df.drop(columns="Mortality rate")

# %%
slave_voyages_df.columns
# Out:
# Index(['Voyage ID', 'Vessel name',
#        'Voyage ship place where vessel registered ',
#        'Voyage itinerary imputed port where began (ptdepimp) place',
#        'Voyage itinerary imputed principal place of slave purchase (mjbyptimp) ',
#        'Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place',
#        'Total embarked', 'Year of arrival at port of disembarkation',
#        'Slaves arrived at 1st port', 'Percent men', 'Percent women',
#        'Percent children', 'Captain's name', 'African resistance'],
#       dtype='object')

# %% [markdown]
# ## Add Columns

# %% [markdown]
# To add a column, we simply put a new column name in square brackets and set it equal to whatever we want the new column to be.
#
# For example, if we wanted to create new columns for the total women and men aboard each voyage, we could set them equal to the product of the "total_disembarked" column * the "percent_women" / "percent_men" columns.

# %%
slave_voyages_df['Total women'] = slave_voyages_df['Total embarked'] * slave_voyages_df['Percent women']

# %%
slave_voyages_df['Total men'] = slave_voyages_df['Total embarked'] * slave_voyages_df['Percent men']

# %% [markdown]
# If we scroll all the way to the right side of the DataFrame, we can see that these columns have been added.

# %%
slave_voyages_df.head(1)
# Out:
#    Voyage ID      Vessel name Voyage ship place where vessel registered   \
# 0          1  Pastora de Lima                                        NaN
#
#   Voyage itinerary imputed port where began (ptdepimp) place  \
# 0                                     Rio de Janeiro
#
#   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 0                                         Mozambique
#
#   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 0                            Bahia, port unspecified
#
#    Total embarked  Year of arrival at port of disembarkation  \
# 0             NaN                                       1817
#
#    Slaves arrived at 1st port  Percent men  Percent women  Percent children  \
# 0                       290.0          NaN            NaN               NaN
#
#       Captain's name African resistance  Total women  Total men
# 0  Dias, Manoel José                NaN          NaN        NaN

# %% [markdown]
# ## Sort Columns

# %% [markdown]
# We can sort a DataFrame with the `.sort_values()` method, inside of which we include the parameter `by=` and indicate the name of the column we want to sort by (written in quotation marks).
#
# For example, we can sort the DataFrame by the voyages that had the largest proportion of enslaved women aboard.

# %%
slave_voyages_df.sort_values(by='Percent women', ascending=False)
# Out:
#        Voyage ID       Vessel name Voyage ship place where vessel registered   \
# 6438       14378  S José Diligente                                        NaN
# 6087       11330           Prinses                                        NaN
# 14487      31883         Elisabeth                                        NaN
# 10466      21566             S Jan                                        NaN
# 6779       14868       Descubridor                                        NaN
# ...          ...               ...                                        ...
# 30442     900232         Tourville                                        NaN
# 30443     900233      General Rêgo                                        NaN
# 30444     900234  Duas Clementinas                                        NaN
# 30445     900236        Rio Tâmega                                        NaN
# 30446     900237              Rosa                                        NaN
#
#       Voyage itinerary imputed port where began (ptdepimp) place  \
# 6438                                                 NaN
# 6087                        Pernambuco, port unspecified
# 14487                                              Goree
# 10466                                            Zeeland
# 6779                                                 NaN
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                 Southeast Brazil, port unspecified
# 30444                                     Rio de Janeiro
# 30445                 Southeast Brazil, port unspecified
# 30446                                     Rio de Janeiro
#
#       Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 6438                                              Luanda
# 6087                                              Luanda
# 14487  Senegambia and offshore Atlantic, port unspeci...
# 10466                                              Bonny
# 6779                           Africa., port unspecified
# ...                                                  ...
# 30442  West Central Africa and St. Helena, port unspe...
# 30443                                           Benguela
# 30444                                           Benguela
# 30445                                           Benguela
# 30446                                           Benguela
#
#       Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 6438                                              Havana
# 6087                        Pernambuco, port unspecified
# 14487                                       Cap Francais
# 10466                          Jamaica, port unspecified
# 6779                                              Havana
# ...                                                  ...
# 30442                                     Rio de Janeiro
# 30443                                     Rio de Janeiro
# 30444                                     Rio de Janeiro
# 30445                                     Rio de Janeiro
# 30446                                     Rio de Janeiro
#
#        Total embarked  Year of arrival at port of disembarkation  \
# 6438              NaN                                       1819
# 6087            152.0                                       1642
# 14487           120.0                                       1715
# 10466           195.0                                       1659
# 6779              NaN                                       1819
# ...               ...                                        ...
# 30442             NaN                                       1848
# 30443             NaN                                       1849
# 30444             NaN                                       1850
# 30445             NaN                                       1851
# 30446             NaN                                       1851
#
#        Slaves arrived at 1st port  Percent men  Percent women  \
# 6438                         73.0      0.00000        1.00000
# 6087                          NaN      0.01190        0.98810
# 14487                        99.0      0.09091        0.74747
# 10466                        85.0      0.27500        0.72500
# 6779                        161.0      0.28571        0.71429
# ...                           ...          ...            ...
# 30442                         NaN          NaN            NaN
# 30443                         NaN          NaN            NaN
# 30444                         NaN          NaN            NaN
# 30445                         NaN          NaN            NaN
# 30446                         NaN          NaN            NaN
#
#        Percent children               Captain's name African resistance  \
# 6438            0.00000                       Estepa                NaN
# 6087            0.44737                          NaN                NaN
# 14487           0.16162                     Beliveau                NaN
# 10466           0.05882  Veer, Adriaen Blaes van der                NaN
# 6779            0.00000           Benoit<br/> Valdes                NaN
# ...                 ...                          ...                ...
# 30442               NaN                         Alex                NaN
# 30443               NaN                          NaN                NaN
# 30444               NaN                          NaN                NaN
# 30445               NaN                          NaN                NaN
# 30446               NaN                          NaN                NaN
#
#        Total women  Total men
# 6438           NaN        NaN
# 6087      150.1912     1.8088
# 14487      89.6964    10.9092
# 10466     141.3750    53.6250
# 6779           NaN        NaN
# ...            ...        ...
# 30442          NaN        NaN
# 30443          NaN        NaN
# 30444          NaN        NaN
# 30445          NaN        NaN
# 30446          NaN        NaN
#
# [30447 rows x 16 columns]

# %% [markdown]
# By default, pandas will sort in "ascending" order, from the smallest value to the largest value. If we want to sort the largest values first, we need to include another parameter `ascending=False`.

# %% [markdown]
# Because the DataFrame is truncated when it has more than 100 rows, we can use a Python list slice to view the top 30 (or any number less than 100) voyages with enslaved women aboard.

# %%
slave_voyages_df.sort_values(by='Percent women', ascending=False)[:30]
# Out:
#        Voyage ID            Vessel name  \
# 6438       14378       S José Diligente
# 6087       11330                Prinses
# 14487      31883              Elisabeth
# 10466      21566                  S Jan
# 6779       14868            Descubridor
# 6083       11326              Overijsel
# 6769       14857               Vencedor
# 6432       14372       Supremo Habanero
# 15470      33087  Saint Jean Triomphant
# 24076      75489                Florida
# 5290       10278                Rusthof
# 4685        9558              Elizabeth
# 4679        9552             Blackamore
# 8941       18138                   Fame
# 4686        9559               Allepine
# 24294      76460   Royal African Packet
# 5025        9980                  Lenox
# 30192      96099                  S Ana
# 6435       14375                Clarita
# 4965        9918                African
# 14490      31886          Duc d'Orléans
# 15312      32873                Prothée
# 15494      33119            Don de Dieu
# 4886        9838                Francis
# 5032        9987                   Vine
# 29708      92352         John and Betty
# 4757        9669               Jefferie
# 12917      30111                 Fidèle
# 4974        9927                   Hope
# 4945        9898                 Arthur
#
#       Voyage ship place where vessel registered   \
# 6438                                         NaN
# 6087                                         NaN
# 14487                                        NaN
# 10466                                        NaN
# 6779                                         NaN
# 6083                                         NaN
# 6769                                         NaN
# 6432                                         NaN
# 15470                                        NaN
# 24076                                        NaN
# 5290                                         NaN
# 4685                                         NaN
# 4679                                         NaN
# 8941                                         NaN
# 4686                                         NaN
# 24294                                        NaN
# 5025                                         NaN
# 30192                                        NaN
# 6435                                         NaN
# 4965                                         NaN
# 14490                                        NaN
# 15312                                        NaN
# 15494                                        NaN
# 4886                                         NaN
# 5032                                         NaN
# 29708                                  Liverpool
# 4757                                         NaN
# 12917                                        NaN
# 4974                                         NaN
# 4945                                         NaN
#
#       Voyage itinerary imputed port where began (ptdepimp) place  \
# 6438                                                 NaN
# 6087                        Pernambuco, port unspecified
# 14487                                              Goree
# 10466                                            Zeeland
# 6779                                                 NaN
# 6083                        Pernambuco, port unspecified
# 6769                                                 NaN
# 6432                                              Havana
# 15470                       Martinique, port unspecified
# 24076                                             London
# 5290                                          Vlissingen
# 4685                                                 NaN
# 4679                                                 NaN
# 8941                                             Bristol
# 4686                                                 NaN
# 24294                                             London
# 5025                                              London
# 30192                                                NaN
# 6435                                                 NaN
# 4965                                              London
# 14490                                           Honfleur
# 15312                                            Lorient
# 15494                                         Saint-Malo
# 4886                                              London
# 5032                                              London
# 29708                                          Liverpool
# 4757                                              London
# 12917                                             Nantes
# 4974                                              London
# 4945                                              London
#
#       Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 6438                                              Luanda
# 6087                                              Luanda
# 14487  Senegambia and offshore Atlantic, port unspeci...
# 10466                                              Bonny
# 6779                           Africa., port unspecified
# 6083                                              Luanda
# 6769                           Africa., port unspecified
# 6432                                              Ambriz
# 15470                                              Benin
# 24076                                            Calabar
# 5290                                             Jacquin
# 4685                                         New Calabar
# 4679                                               Ardra
# 8941                                             Calabar
# 4686   Bight of Biafra and Gulf of Guinea Islands, po...
# 24294                                            Cabinda
# 5025                                             Calabar
# 30192                          Africa., port unspecified
# 6435                                              Luanda
# 4965                        Gold Coast, port unspecified
# 14490                                              Goree
# 15312  Senegambia and offshore Atlantic, port unspeci...
# 15494                                            Formosa
# 4886                                         New Calabar
# 5032                                             Calabar
# 29708                          Africa., port unspecified
# 4757                                   Cape Coast Castle
# 12917                          Africa., port unspecified
# 4974                                         New Calabar
# 4945                                             Calabar
#
#       Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 6438                                              Havana
# 6087                        Pernambuco, port unspecified
# 14487                                       Cap Francais
# 10466                          Jamaica, port unspecified
# 6779                                              Havana
# 6083                        Pernambuco, port unspecified
# 6769                                              Havana
# 6432                                              Havana
# 15470                       Martinique, port unspecified
# 24076                               Saint John (Antigua)
# 5290                                            Suriname
# 4685                          Barbados, port unspecified
# 4679                          Barbados, port unspecified
# 8941                           Grenada, port unspecified
# 4686                           Jamaica, port unspecified
# 24294                          Jamaica, port unspecified
# 5025                          Barbados, port unspecified
# 30192                                       Buenos Aires
# 6435                                              Havana
# 4965                           Jamaica, port unspecified
# 14490                                            Leogane
# 15312                                       Cap Francais
# 15494                       Martinique, port unspecified
# 4886                                   Newcastle (Nevis)
# 5032                           Jamaica, port unspecified
# 29708                                       Rappahannock
# 4757                           Jamaica, port unspecified
# 12917                                            Cayenne
# 4974                          Barbados, port unspecified
# 4945                           Jamaica, port unspecified
#
#        Total embarked  Year of arrival at port of disembarkation  \
# 6438              NaN                                       1819
# 6087            152.0                                       1642
# 14487           120.0                                       1715
# 10466           195.0                                       1659
# 6779              NaN                                       1819
# 6083             78.0                                       1642
# 6769              NaN                                       1818
# 6432              NaN                                       1819
# 15470             NaN                                       1721
# 24076           360.0                                       1714
# 5290            716.0                                       1734
# 4685              NaN                                       1664
# 4679            373.0                                       1663
# 8941            200.0                                       1792
# 4686              NaN                                       1664
# 24294           201.0                                       1723
# 5025              NaN                                       1677
# 30192           160.0                                       1804
# 6435              NaN                                       1819
# 4965            400.0                                       1681
# 14490           411.0                                       1716
# 15312           210.0                                       1725
# 15494           215.0                                       1720
# 4886            267.0                                       1686
# 5032              NaN                                       1678
# 29708             NaN                                       1727
# 4757              NaN                                       1685
# 12917             NaN                                       1719
# 4974            232.0                                       1681
# 4945              NaN                                       1682
#
#        Slaves arrived at 1st port  Percent men  Percent women  \
# 6438                         73.0      0.00000        1.00000
# 6087                          NaN      0.01190        0.98810
# 14487                        99.0      0.09091        0.74747
# 10466                        85.0      0.27500        0.72500
# 6779                        161.0      0.28571        0.71429
# 6083                          NaN      0.28889        0.71111
# 6769                         62.0      0.00000        0.69355
# 6432                        149.0      0.31544        0.68456
# 15470                        59.0      0.16949        0.67797
# 24076                       240.0      0.33333        0.66667
# 5290                        374.0      0.24441        0.66480
# 4685                        168.0      0.26087        0.65217
# 4679                        150.0      0.35333        0.64667
# 8941                        135.0      0.29798        0.64646
# 4686                        185.0      0.22703        0.64324
# 24294                       198.0      0.09091        0.64141
# 5025                          NaN      0.32895        0.63816
# 30192                        81.0      0.31667        0.63333
# 6435                        209.0      0.37799        0.62201
# 4965                        170.0      0.30120        0.62048
# 14490                       402.0      0.37975        0.62025
# 15312                       207.0      0.33333        0.61353
# 15494                       116.0      0.12931        0.61207
# 4886                        111.0      0.24590        0.60656
# 5032                          NaN      0.34868        0.60526
# 29708                       140.0      0.39560        0.60440
# 4757                        242.0      0.40083        0.59917
# 12917                        42.0      0.23810        0.59524
# 4974                        130.0      0.33846        0.59231
# 4945                          NaN      0.32710        0.58879
#
#        Percent children                              Captain's name  \
# 6438            0.00000                                      Estepa
# 6087            0.44737                                         NaN
# 14487           0.16162                                    Beliveau
# 10466           0.05882                 Veer, Adriaen Blaes van der
# 6779            0.00000                          Benoit<br/> Valdes
# 6083            0.00000                     Langman, Claes Arentsen
# 6769            0.30645                                   Iturrondo
# 6432            0.00000                               Blanco, Pedro
# 15470           0.15254                                  Gaulart, J
# 24076           0.16667                               Payne, Samuel
# 5290            0.09078  Bovenmans, Anthony<br/> Theunissen, Willem
# 4685            0.08696                            Francis, William
# 4679            0.00000                                      Bowles
# 8941            0.06965                            Jenkins, William
# 4686            0.12973                           Thwaites, William
# 24294           0.26768                             Cornwell, Henry
# 5025            0.03289                               Wilkins, Amos
# 30192           0.05000                Amaro, Rodriguez de Oliveira
# 6435            0.00000                           Carballo, Alberto
# 4965            0.07831                               Mingham, John
# 14490           0.20736                       Villers, Chevalier de
# 15312           0.05314                                  Hantier, J
# 15494           0.25862                 Masson Du Bocage, Guillaume
# 4886            0.14754                               Wimple, Ralph
# 5032            0.04605                               Coleman, John
# 29708           0.35000                             Denton, William
# 4757            0.00000                             Daile, Benjamin
# 12917           0.16667                               Bonneau, Jean
# 4974            0.06923                                Grible, John
# 4945            0.08411                               Penny, George
#
#        African resistance  Total women  Total men
# 6438                  NaN          NaN        NaN
# 6087                  NaN    150.19120    1.80880
# 14487                 NaN     89.69640   10.90920
# 10466                 NaN    141.37500   53.62500
# 6779                  NaN          NaN        NaN
# 6083                  NaN     55.46658   22.53342
# 6769                  NaN          NaN        NaN
# 6432                  NaN          NaN        NaN
# 15470                 NaN          NaN        NaN
# 24076                 NaN    240.00120  119.99880
# 5290                  NaN    475.99680  174.99756
# 4685                  NaN          NaN        NaN
# 4679                  NaN    241.20791  131.79209
# 8941                  NaN    129.29200   59.59600
# 4686                  NaN          NaN        NaN
# 24294                 NaN    128.92341   18.27291
# 5025                  NaN          NaN        NaN
# 30192                 NaN    101.33280   50.66720
# 6435                  NaN          NaN        NaN
# 4965                  NaN    248.19200  120.48000
# 14490                 NaN    254.92275  156.07725
# 15312                 NaN    128.84130   69.99930
# 15494  Slave insurrection    131.59505   27.80165
# 4886                  NaN    161.95152   65.65530
# 5032                  NaN          NaN        NaN
# 29708                 NaN          NaN        NaN
# 4757                  NaN          NaN        NaN
# 12917                 NaN          NaN        NaN
# 4974                  NaN    137.41592   78.52272
# 4945                  NaN          NaN        NaN

# %% [markdown]
# If we want to sort a Series object, we don't need to use the `by=` paramter.

# %%
slave_voyages_df['Total women'].sort_values(ascending=False)
# Out:
# 5290     475.99680
# 5236     303.00018
# 4823     301.76400
# 4806     295.85644
# 4807     292.37325
#            ...
# 30442          NaN
# 30443          NaN
# 30444          NaN
# 30445          NaN
# 30446          NaN
# Name: Total women, Length: 30447, dtype: float64

# %% [markdown]
# ## Calculate Columns

# %% [markdown]
# We can do different calculations on columns with built-in Pandas functions. These calculations will ignore `NaN` values.

# %% [markdown]
# | Pandas calculations | Explanation                         |
# |----------|-------------------------------------|
# | `.count()`    | Number of observations    |
# | `.sum()`      | Sum of values                       |
# | `.mean()`     | Mean of values                      |
# | `.median()`   | Median of values         |
# | `.min()`      | Minimum                             |
# | `.max()`      | Maximum                             |
# | `.mode()`     | Mode                                |
# | `.std()`      | Unbiased standard deviation         |

# %% [markdown]
# For example, to find the average proprotion of enslaved women aboard the voyages (for voyages that have this information), we can use the `.mean()` method.

# %%
slave_voyages_df['Percent women'].mean()
# Out:
# 0.27317198351793875

# %% [markdown]
# There were on average 27% enslaved women aboard the voyages for voyages that recorded this information.

# %%
slave_voyages_df['Percent women'].max()
# Out:
# 1.0

# %% [markdown]
# The highest percentage of women aboard the slave voyages was 100%. We can use this calculation as a filter to identify the voyage(s) with this maximum value.

# %%
slave_voyages_df[slave_voyages_df['Percent women'] == slave_voyages_df['Percent women'].max()]
# Out:
#       Voyage ID       Vessel name Voyage ship place where vessel registered   \
# 6438      14378  S José Diligente                                        NaN
#
#      Voyage itinerary imputed port where began (ptdepimp) place  \
# 6438                                                NaN
#
#      Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# 6438                                             Luanda
#
#      Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# 6438                                             Havana
#
#       Total embarked  Year of arrival at port of disembarkation  \
# 6438             NaN                                       1819
#
#       Slaves arrived at 1st port  Percent men  Percent women  \
# 6438                        73.0          0.0            1.0
#
#       Percent children Captain's name African resistance  Total women  \
# 6438               0.0         Estepa                NaN          NaN
#
#       Total men
# 6438        NaN

# %% [markdown]
# According to the Trans-Atlantic Slave Trade Database, the 1819 voyage of the S Josee Diligente had 100% enslaved women aboard.

# %% [markdown]
# As demonstrated previously, we can also perform calculations with columns themselves.

# %%
(slave_voyages_df['Total embarked'] * slave_voyages_df['Percent women']).max()
# Out:
# 475.99679999999995

# %% [markdown]
# ## Groupby Columns

# %% [markdown]
# The Pandas function`.groupby()` allows us to group data and perform calculations on the groups.
#
# For example, Jennifer Morgan writes about how some nations recorded more information about the gender of the enslaved people aboard their voyages than other nations did. To see the breakdown of gender information by nation, we can use a `.groupby()` function.
#
# The first step to using groupby is to type the name of the DataFrame followed by `.groupby()` with the column we'd like to aggregate based on, such as "national_affiliation."

# %%
slave_voyages_df.groupby('Voyage ship place where vessel registered ')

# %% [markdown]
# This action will created a [GroupBy object](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html). We can perform calculations on this grouped data, such as counting the number of non-blank values in each column for each nation.

# %%
slave_voyages_df.groupby('Voyage ship place where vessel registered ').count()
# Out:
#                                             Voyage ID  Vessel name  \
# Voyage ship place where vessel registered
# Alicante                                            1            1
# Amsterdam                                          11           11
# Angola (possibly New Calabar)                       1            1
# Antigua, port unspecified                          15           15
# Bahia, port unspecified                            55           55
# ...                                               ...          ...
# Whitby                                              2            2
# Whitehaven                                         38           38
# Williamsburg                                        5            5
# Youghal                                             1            1
# Zeeland                                            20           20
#
#                                             Voyage itinerary imputed port where began (ptdepimp) place  \
# Voyage ship place where vessel registered
# Alicante                                                                                    1
# Amsterdam                                                                                   9
# Angola (possibly New Calabar)                                                               1
# Antigua, port unspecified                                                                  15
# Bahia, port unspecified                                                                    55
# ...                                                                                       ...
# Whitby                                                                                      2
# Whitehaven                                                                                 37
# Williamsburg                                                                                4
# Youghal                                                                                     1
# Zeeland                                                                                    17
#
#                                             Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# Voyage ship place where vessel registered
# Alicante                                                                                    1
# Amsterdam                                                                                  11
# Angola (possibly New Calabar)                                                               1
# Antigua, port unspecified                                                                  15
# Bahia, port unspecified                                                                    55
# ...                                                                                       ...
# Whitby                                                                                      2
# Whitehaven                                                                                 38
# Williamsburg                                                                                5
# Youghal                                                                                     1
# Zeeland                                                                                    20
#
#                                             Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# Voyage ship place where vessel registered
# Alicante                                                                                    1
# Amsterdam                                                                                  11
# Angola (possibly New Calabar)                                                               1
# Antigua, port unspecified                                                                  15
# Bahia, port unspecified                                                                    55
# ...                                                                                       ...
# Whitby                                                                                      2
# Whitehaven                                                                                 38
# Williamsburg                                                                                5
# Youghal                                                                                     1
# Zeeland                                                                                    20
#
#                                             Total embarked  \
# Voyage ship place where vessel registered
# Alicante                                                 1
# Amsterdam                                                6
# Angola (possibly New Calabar)                            1
# Antigua, port unspecified                                6
# Bahia, port unspecified                                 49
# ...                                                    ...
# Whitby                                                   1
# Whitehaven                                               4
# Williamsburg                                             0
# Youghal                                                  0
# Zeeland                                                  1
#
#                                             Year of arrival at port of disembarkation  \
# Voyage ship place where vessel registered
# Alicante                                                                            1
# Amsterdam                                                                          11
# Angola (possibly New Calabar)                                                       1
# Antigua, port unspecified                                                          15
# Bahia, port unspecified                                                            55
# ...                                                                               ...
# Whitby                                                                              2
# Whitehaven                                                                         38
# Williamsburg                                                                        5
# Youghal                                                                             1
# Zeeland                                                                            20
#
#                                             Slaves arrived at 1st port  \
# Voyage ship place where vessel registered
# Alicante                                                             0
# Amsterdam                                                           11
# Angola (possibly New Calabar)                                        0
# Antigua, port unspecified                                            7
# Bahia, port unspecified                                             27
# ...                                                                ...
# Whitby                                                               2
# Whitehaven                                                          34
# Williamsburg                                                         3
# Youghal                                                              1
# Zeeland                                                             13
#
#                                             Percent men  Percent women  \
# Voyage ship place where vessel registered
# Alicante                                              0              0
# Amsterdam                                             6              6
# Angola (possibly New Calabar)                         0              0
# Antigua, port unspecified                             1              1
# Bahia, port unspecified                               0              0
# ...                                                 ...            ...
# Whitby                                                0              0
# Whitehaven                                            1              1
# Williamsburg                                          0              0
# Youghal                                               0              0
# Zeeland                                              11             11
#
#                                             Percent children  Captain's name  \
# Voyage ship place where vessel registered
# Alicante                                                   0               1
# Amsterdam                                                  6              10
# Angola (possibly New Calabar)                              0               0
# Antigua, port unspecified                                  1              15
# Bahia, port unspecified                                    1              32
# ...                                                      ...             ...
# Whitby                                                     0               2
# Whitehaven                                                 1              38
# Williamsburg                                               0               5
# Youghal                                                    0               1
# Zeeland                                                   11              18
#
#                                             African resistance  Total women  \
# Voyage ship place where vessel registered
# Alicante                                                     0            0
# Amsterdam                                                    2            3
# Angola (possibly New Calabar)                                0            0
# Antigua, port unspecified                                    0            1
# Bahia, port unspecified                                      0            0
# ...                                                        ...          ...
# Whitby                                                       0            0
# Whitehaven                                                   1            0
# Williamsburg                                                 0            0
# Youghal                                                      0            0
# Zeeland                                                      0            0
#
#                                             Total men
# Voyage ship place where vessel registered
# Alicante                                            0
# Amsterdam                                           3
# Angola (possibly New Calabar)                       0
# Antigua, port unspecified                           1
# Bahia, port unspecified                             0
# ...                                               ...
# Whitby                                              0
# Whitehaven                                          0
# Williamsburg                                        0
# Youghal                                             0
# Zeeland                                             0
#
# [134 rows x 15 columns]

# %% [markdown]
# On England's Slave Ship Records
# > For example, patterns emerge that suggest that English slave ship captains provided the most data related to the age or sex characteristics of the captives they transported and sold into slavery...The degree to which the practice of recording the sex of the passengers on board accords to national origin raises some interesting questions about the possible correlations between certain notational and national presumptions of accountability.
#
# -Jennifer Morgan, ["Accounting for 'The Most Excruciating Torment'"](https://read.dukeupress.edu/history-of-the-present/article-abstract/6/2/184/153282/Accounting-for-The-Most-Excruciating-Torment?redirectedFrom=PDF)

# %% [markdown]
# We can also isolate only the "percent_women" column.

# %%
slave_voyages_df.groupby('Voyage ship place where vessel registered ').count()['Percent women']
# Out:
# Voyage ship place where vessel registered
# Alicante                          0
# Amsterdam                         6
# Angola (possibly New Calabar)     0
# Antigua, port unspecified         1
# Bahia, port unspecified           0
#                                  ..
# Whitby                            0
# Whitehaven                        1
# Williamsburg                      0
# Youghal                           0
# Zeeland                          11
# Name: Percent women, Length: 134, dtype: int64

# %%
slave_voyages_df.groupby('Voyage ship place where vessel registered ')['Percent women'].count().sort_values(ascending=False)
# Out:
# Voyage ship place where vessel registered
# Liverpool                        285
# Denmark, port unspecified         73
# Newport                           65
# Bristol (RI)                      51
# London                            46
#                                 ...
# Youghal                            0
# Nantes                             0
# Netherlands, port unspecified      0
# Nevis, port unspecified            0
# Alicante                           0
# Name: Percent women, Length: 134, dtype: int64

# %% [markdown]
# > Line Breaks:
# If a line of code gets too long, you can create a line break with a backslash `\`

# %%
slave_voyages_df.groupby('Voyage ship place where vessel registered ')['Percent women'].count()\
.sort_values(ascending=False).plot(kind='bar', title='Trans-Atlantic Slave Trade (Americas): \n Slave Voyages with Recorded Gender Information')

# %% [markdown]
# ## Make Time Series with Groupby

# %% [markdown]
# To make a time series, we would typically want to convert our date column into datetime values rather than integers.

# %%
slave_voyages_df['Year of arrival at port of disembarkation'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Datetime values allow us to do special things that we can't do with regular integers and floats, such as extract just the year, month, week, day, or second from any date or aggregate based on any of the above.
#
# Since we're only working with year information, however, we can make some simple time series plots just by grouping by the year column and performing calculations on those year groupings, such as calculating the average percentage of enslaved women aboard the voyages over time.

# %%
slave_voyages_df.groupby('Year of arrival at port of disembarkation')['Percent women'].mean()\
.plot(title="Trans-Atlantic Slave Trade (Americas):\nAverage Percentage of Enslaved Women on Voyages")

# %% [markdown]
# We can do the same thing with the total number of women, this time taking the sum for every year.

# %%
slave_voyages_df.groupby('Year of arrival at port of disembarkation')['Total women'].sum()\
.plot(kind='area', title="Trans-Atlantic Slave Trade (Americas):\nTotal Number of Enslaved Women on Voyages")

# %% [markdown]
# We can plot multiple columns at the same time by using two square brackets. For example, we can compare the total number of women and men aboard the voyages.

# %%
slave_voyages_df.groupby('Year of arrival at port of disembarkation')[['Total women', 'Total men']].sum()\
.plot(kind='area', title="Trans-Atlantic Slave Trade (Americas):\nTotal Number of Enslaved Women and Men on Voyages")

# %% [markdown]
# Finally, we can also add in the total number of enslaved people who embarked on the voyages, offering a perspective of how mcuh gender information we have about the voyages compared to the total number of voyages.

# %%
slave_voyages_df.groupby('Year of arrival at port of disembarkation')[['Total women', 'Total men', 'Total embarked']].sum()\
.plot(kind='area', title='Trans-Atlantic Slave Trade (Americas):\nTotal Number of Enslaved People on Voyages')
