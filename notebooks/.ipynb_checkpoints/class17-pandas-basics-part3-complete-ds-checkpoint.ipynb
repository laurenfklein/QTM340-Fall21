# %% [markdown]
# # Pandas Basics — Part 3

# %% [markdown]
# _I adapted this notebook from Melanie Walsh's [Pandas Basics — Part 3](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Data-Analysis/Pandas-Basics-Part3.html), which is from her online textbook [Introduction to Cultural Analytics & Python](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/welcome.html)_

# %% [markdown]
# In this lesson, we're going to introduce more fundamentals of [pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html), a powerful Python library for working with tabular data like CSV files.
#
# We will review skills learned from the last two lessons and introduce how to:
#
# - Check for duplicate data
# - Clean and transform data
# - Manipulate string data
# - Apply functions
# - Reset index
# - Bonus! Create an interactive data viz

# %% [markdown]
# ## Dataset
# ### *The Pudding*'s Film Dialogue Data

# %% [markdown]
# ```{epigraph}
# Lately, Hollywood has been taking so much shit for rampant sexism and racism. The prevailing theme: white men dominate movie roles.
# But it’s all rhetoric and no data, which gets us nowhere in terms of having an informed discussion. How many movies are actually about men? What changes by genre, era, or box-office revenue? What circumstances generate more diversity?
# ```
# -- Hannah Anderson and Matt Daniels, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/)

# %% [markdown]
# The dataset that we're working with in this lesson is taken from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). The dataset provides information about 2,000 films from 1925 to 2015, including characters’ names, genders, ages, how many words each character spoke in each film, the release year of each film, and how much money the film grossed. They included character gender information because they wanted to contribute data to a broader conversation about how "white men dominate movie roles."
#
# Yet transforming complex social constructs like gender into quantifiable data is tricky and historically fraught. They claim, in fact, that one of the [most frequently asked questions](https://medium.com/@matthew_daniels/faq-for-the-film-dialogue-by-gender-project-40078209f751) about the piece is about gender: “Wait, but let’s talk about gender. How do you know the monster in Monsters Inc. is a boy!" The short answer is that they don't. To determine character gender, they used actors' IMDB information, which they acknowledge is an imperfect approach: "Sometimes, women voice male characters. Bart Simpson, for example, is voiced by a woman. We’re aware that this means some of the data is wrong, AND we’re still fine with the methodology and approach."

# %% [markdown]
# **What do we lose because of how this dataset treats gender?**

# %% [markdown]
# * ANSWER HERE
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Set Display Settings

# %% [markdown]
# By default, Pandas will display 60 rows and 20 columns. I often change [pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# ## Read in CSV File

# %% [markdown]
# To read in a CSV file, we will use the function `pd.read_csv()` and insert the name of our desired file path.

# %%
film_df = pd.read_csv('../docs/Pudding-Film-Dialogue-Clean.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# When reading in the CSV file, we also specified the `encoding` and `delimiter`. The `delimiter` parameter specifies the character that separates or "delimits" the columns in our dataset. For CSV files, the delimiter will most often be a comma. (CSV is short for *Comma Separated Values*.) Sometimes, however, the delimiter of a CSV file might be a tab (`/t`) or, more rarely, another character.

# %% [markdown]
# ## Display Data

# %% [markdown]
# We can display a DataFrame in a Jupyter notebook simply by running a cell with the variable name of the DataFrame.

# %% [markdown]
# `NaN` is the Pandas value for any missing data. See ["Working with missing data"](https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html?highlight=nan) for more information.

# %%
film_df
# Out:
#        script_id        character  words gender   age  \
# 0            280            Betty    311  Woman  35.0
# 1            280  Carolyn Johnson    873  Woman   NaN
# 2            280          Eleanor    138  Woman   NaN
# 3            280  Francesca Johns   2251  Woman  46.0
# 4            280            Madge    190  Woman  46.0
# ...          ...              ...    ...    ...   ...
# 23043       9254          Lumiere   1063    Man  56.0
# 23044       9254          Maurice   1107    Man  71.0
# 23045       9254  Monsieur D'Arqu    114    Man  58.0
# 23046       9254       Mrs. Potts    564  Woman  66.0
# 23047       9254         Wardrobe    121  Woman  54.0
#
#                                title  release_year  gross  \
# 0      The Bridges of Madison County          1995  142.0
# 1      The Bridges of Madison County          1995  142.0
# 2      The Bridges of Madison County          1995  142.0
# 3      The Bridges of Madison County          1995  142.0
# 4      The Bridges of Madison County          1995  142.0
# ...                              ...           ...    ...
# 23043           Beauty and the Beast          1991  452.0
# 23044           Beauty and the Beast          1991  452.0
# 23045           Beauty and the Beast          1991  452.0
# 23046           Beauty and the Beast          1991  452.0
# 23047           Beauty and the Beast          1991  452.0
#
#        proportion_of_dialogue  after_2000
# 0                    0.048639       False
# 1                    0.136534       False
# 2                    0.021583       False
# 3                    0.352049       False
# 4                    0.029715       False
# ...                       ...         ...
# 23043                0.104636       False
# 23044                0.108967       False
# 23045                0.011222       False
# 23046                0.055517       False
# 23047                0.011911       False
#
# [23048 rows x 10 columns]

# %% [markdown]
# There are a few important things to note about the DataFrame displayed here:
#
# * Index
#     * The ascending numbers in the very left-hand column of the DataFrame is called the Pandas *Index*. You can select rows based on the Index.
#     * By default, the Index is a sequence of numbers starting with zero. However, you can change the Index to something else, such as one of the columns in your dataset.
#
# * Truncation
#     * The DataFrame is truncated, signaled by the ellipses in the middle `...` of every column.
#     * The DataFrame is truncated because we set our default display settings to 100 rows. Anything more than 100 rows will be truncated. To display all the rows, we would need to alter Pandas' default display settings yet again.
#
# * Rows x Columns
#     * Pandas reports how many rows and columns are in this dataset at the bottom of the output (23,048 x 10 columns).

# %% [markdown]
# ### Display First *n* Rows
#
# To look at the first *n* rows in a DataFrame, we can use a method called `.head()`.

# %%
film_df.head(10)
# Out:
#    script_id        character  words gender   age  \
# 0        280            Betty    311  Woman  35.0
# 1        280  Carolyn Johnson    873  Woman   NaN
# 2        280          Eleanor    138  Woman   NaN
# 3        280  Francesca Johns   2251  Woman  46.0
# 4        280            Madge    190  Woman  46.0
# 5        280  Michael Johnson    723    Man  38.0
# 6        280   Robert Kincaid   1908    Man  65.0
# 7        623     Bobby Korfin    328    Man   NaN
# 8        623  Daphne Handlova    409  Woman  28.0
# 9        623  Deputy Chief Fi    347    Man   NaN
#
#                            title  release_year  gross  proportion_of_dialogue  \
# 0  The Bridges of Madison County          1995  142.0                0.048639
# 1  The Bridges of Madison County          1995  142.0                0.136534
# 2  The Bridges of Madison County          1995  142.0                0.021583
# 3  The Bridges of Madison County          1995  142.0                0.352049
# 4  The Bridges of Madison County          1995  142.0                0.029715
# 5  The Bridges of Madison County          1995  142.0                0.113075
# 6  The Bridges of Madison County          1995  142.0                0.298405
# 7                     15 Minutes          2001   37.0                0.036012
# 8                     15 Minutes          2001   37.0                0.044906
# 9                     15 Minutes          2001   37.0                0.038098
#
#    after_2000
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# 8        True
# 9        True

# %% [markdown]
# ### Display Random Sample

# %% [markdown]
# To look at a random sample of rows, we can use the `.sample()` method.

# %%
film_df.sample(10)
# Out:
#        script_id        character  words gender   age                 title  \
# 421          726              Sal    919  Woman  40.0             The Beach
# 13864       4575           George    249    Man  66.0      Made in Dagenham
# 20089       7742          Old Guy    409    Man   NaN             The Rover
# 19741       7597              Don    577    Man  46.0        28 Weeks Later
# 10792       3473  Connie Zirpollo    350  Woman  57.0       The Surfer King
# 1320         962            Jenna    295  Woman   NaN               Gothika
# 19153       7325          Officer    139  Woman  36.0  Deliver Us from Evil
# 21668       8431  Gorobei Katayam    400    Man  34.0         Seven Samurai
# 18075       6724       Mr. Parker   2916    Man  26.0    The Way of the Gun
# 20223       7808      Sara Thomas   2727  Woman  28.0           Serendipity
#
#        release_year  gross  proportion_of_dialogue  after_2000
# 421            2000   64.0                0.085022        True
# 13864          2010    1.0                0.025187        True
# 20089          2014    1.0                0.072313        True
# 19741          2007   36.0                0.185531        True
# 10792          2006    NaN                0.021974        True
# 1320           2003   85.0                0.020705        True
# 19153          2014   32.0                0.020638        True
# 21668          1954    NaN                0.073842       False
# 18075          2000    9.0                0.250688        True
# 20223          2001   76.0                0.309886        True

# %% [markdown]
# ## Examine Data

# %% [markdown]
# ### Shape

# %% [markdown]
# To explicitly check for how many rows vs columns make up a dataset, we can use the `.shape` method.

# %%
film_df.shape
# Out:
# (23048, 10)

# %% [markdown]
# There are 23,048 rows and 10 columns.

# %% [markdown]
# ### Data Types

# %% [markdown]
# Just like Python has different data types, pandas has different data types, too. These data types are automatically assigned to columns when we read in a CSV file. We can check these Pandas data types with the [`.dtypes` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html).

# %% [markdown]
# | **Pandas Data Type** |  **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `object`         | string                                                                               |
# | `float64`         | float                                               |
# | `int64`       | integer                                                        |
# | `datetime64`       |  date time

# %%
film_df.dtypes
# Out:
# script_id                   int64
# character                  object
# words                       int64
# gender                     object
# age                       float64
# title                      object
# release_year                int64
# gross                     float64
# proportion_of_dialogue    float64
# after_2000                   bool
# dtype: object

# %% [markdown]
# It's important to always check the data types in your DataFrame. For example, sometimes numeric values will accidentally be interpreted as a string object. To perform calculations on this data, you would need to first convert that column from a string to an integer.

# %% [markdown]
# ### Columns

# %% [markdown]
# We can also check the column names of the DataFrame with [`.columns`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html)

# %%
film_df.columns
# Out:
# Index(['script_id', 'character', 'words', 'gender', 'age', 'title',
#        'release_year', 'gross', 'proportion_of_dialogue', 'after_2000'],
#       dtype='object')

# %% [markdown]
# ### Summary Statistics

# %%
film_df.describe(include='all')
# Out:
#            script_id character         words gender           age      title  \
# count   23048.000000     23048  23048.000000  23043  18263.000000      23048
# unique           NaN     17544           NaN      2           NaN       1994
# top              NaN    Doctor           NaN    Man           NaN  Lone Star
# freq             NaN        37           NaN  16132           NaN         40
# mean     4194.784623       NaN    907.871486    NaN     42.382960        NaN
# std      2472.985787       NaN   1399.593759    NaN     59.718859        NaN
# min       280.000000       NaN    101.000000    NaN      3.000000        NaN
# 25%      2095.000000       NaN    193.000000    NaN     30.000000        NaN
# 50%      3694.000000       NaN    396.000000    NaN     39.000000        NaN
# 75%      6219.750000       NaN    980.000000    NaN     50.000000        NaN
# max      9254.000000       NaN  28102.000000    NaN   2013.000000        NaN
#
#         release_year        gross  proportion_of_dialogue after_2000
# count   23048.000000  19387.00000            23048.000000      23048
# unique           NaN          NaN                     NaN          2
# top              NaN          NaN                     NaN       True
# freq             NaN          NaN                     NaN      12632
# mean     1998.133070    106.73637                0.086515        NaN
# std        14.746058    145.85823                0.107745        NaN
# min      1929.000000      0.00000                0.001537        NaN
# 25%      1992.000000     22.00000                0.019771        NaN
# 50%      2001.000000     56.00000                0.042421        NaN
# 75%      2009.000000    136.00000                0.104166        NaN
# max      2015.000000   1798.00000                0.923422        NaN

# %% [markdown]
# Do you notice any outliers, anomalies, or potential problems here?

# %% [markdown]
# * ANSWER HERE
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *
# * *

# %% [markdown]
# The maximum value in the "age" column is 2013! That seems like an error.

# %%
film_df[film_df['age'] == 2013]
# Out:
#        script_id      character  words gender     age  \
# 11639       3737  Lucas Solomon    190    Man  2013.0
#
#                          title  release_year  gross  proportion_of_dialogue  \
# 11639  The Wolf of Wall Street          2013  125.0                0.011077
#
#        after_2000
# 11639        True

# %% [markdown]
# Let's drop this row from the dataset by using the `.drop()` method and the Index number of the row.

# %%
film_df = film_df.drop(11639)

# %% [markdown]
# Now if we look for it again, that row is gone.

# %%
film_df[film_df['age'] == 2013]
# Out:
# Empty DataFrame
# Columns: [script_id, character, words, gender, age, title, release_year, gross, proportion_of_dialogue, after_2000]
# Index: []

# %% [markdown]
# ### Rename Columns

# %%
film_df = film_df.rename(columns={'imdb_character_name': 'character', 'year': 'release_year'})

# %%
film_df.head()
# Out:
#    script_id        character  words gender   age  \
# 0        280            Betty    311  Woman  35.0
# 1        280  Carolyn Johnson    873  Woman   NaN
# 2        280          Eleanor    138  Woman   NaN
# 3        280  Francesca Johns   2251  Woman  46.0
# 4        280            Madge    190  Woman  46.0
#
#                            title  release_year  gross  proportion_of_dialogue  \
# 0  The Bridges of Madison County          1995  142.0                0.048639
# 1  The Bridges of Madison County          1995  142.0                0.136534
# 2  The Bridges of Madison County          1995  142.0                0.021583
# 3  The Bridges of Madison County          1995  142.0                0.352049
# 4  The Bridges of Madison County          1995  142.0                0.029715
#
#    after_2000
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %% [markdown]
# ### Drop Columns

# %%
film_df = film_df.drop(columns='script_id')

# %% [markdown]
# ### Missing Data

# %% [markdown]
# **.isna() / .notna()**

# %% [markdown]
# Pandas has special ways of dealing with missing data. As you may have already noticed, blank rows in a CSV file show up as `NaN` in a pandas DataFrame.

# %% [markdown]
# To filter and count the number of missing/not missing values in a dataset, we can use the special `.isna()` and `.notna()` methods on a DataFrame or Series object.

# %% [markdown]
# The `.isna()` and `.notna()` methods return True/False pairs for each row, which we can use to filter the DataFrame for any rows that have information in a given column.

# %%
film_df[film_df['gender'].isna()]
# Out:
#              character  words gender   age               title  release_year  \
# 7325          Tiny Tim    488    NaN   NaN   The Hebrew Hammer          2003
# 8010   Himself - Walki    312    NaN  90.0                 JFK          1991
# 8011   Himself - With     224    NaN  78.0                 JFK          1991
# 16902  Thomas Hergenro    216    NaN   NaN  Battle of the Year          2013
# 18812            Randy    167    NaN   NaN         Hatchet III          2013
#
#        gross  proportion_of_dialogue  after_2000
# 7325     NaN                0.033720        True
# 8010   145.0                0.005303       False
# 8011   145.0                0.003807       False
# 16902    9.0                0.019626        True
# 18812    NaN                0.033024        True

# %% [markdown]
# This is important information for the sake of better understanding our dataset. But it's also important because `NaN` values are treated as *floats*, not *strings*. If we tried to manipulate this column as text data, we would get an error. For this reason, we're going to replace or "fill" these `NaN` values with the string "No Character Data" by using the `.fillna()` method.

# %%
film_df['gender'] = film_df['gender'].fillna('No Gender Data')

# %%
film_df[film_df['gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [character, words, gender, age, title, release_year, gross, proportion_of_dialogue, after_2000]
# Index: []

# %% [markdown]
# ### Check for Duplicates

# %% [markdown]
# #### Duplicates

# %% [markdown]
# We can check for duplicate rows by using the `.duplicated()` method and setting the parameter `keep=False`, which will display all the duplicated values in the dataset — rather than just the first duplicated value `keep='first'` or the last duplicated value `keep='last'`.

# %%
film_df.duplicated(keep=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23043    False
# 23044    False
# 23045    False
# 23046    False
# 23047    False
# Length: 23047, dtype: bool

# %% [markdown]
# The output above is reporting whether each row in the dataset is a duplicate. We can use the `.duplicated()` method inside a filter to isolate only the rows in the dataframe that are exact duplicates.

# %%
film_df[film_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [character, words, gender, age, title, release_year, gross, proportion_of_dialogue, after_2000]
# Index: []

# %% [markdown]
# We can drop duplicates from the DataFrame with the `.drop_duplicates()` method and choose to keep the first instance of the duplicate or the last instance.

# %%
film_df = film_df.drop_duplicates(keep='first')

# %% [markdown]
# Now if we check the data for duplicates again, they should be all gone.

# %%
film_df[film_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [character, words, gender, age, title, release_year, gross, proportion_of_dialogue, after_2000]
# Index: []

# %% [markdown]
# ## Clean and Transform Data

# %% [markdown]
# ### Pandas `.str` Methods

# %% [markdown]
# Pandas has special [pandas string methods](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#string-methods). Many of them are very similar to Python string methods, except they will transform every single string value in a column, and we have to add `.str` to the method chain.

# %% [markdown]
# | **Pandas String Method** | **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | df['column_name']`.str.lower()`         | makes the string in each row lowercase                                                                                |
# | df['column_name']`.str.upper()`         | makes the string in each row uppercase                                                |
# | df['column_name']`.str.title()`         | makes the string in each row titlecase                                                |
# | df['column_name']`.str.replace('old string', 'new string')`      | replaces `old string` with `new string` for each row |
# | df['column_name']`.str.contains('some string')`      | tests whether string in each row contains "some string" |
# | df['column_name']`.str.split('delim')`          | returns a list of substrings separated by the given delimiter |
# | df['column_name']`.str.join(list)`         | opposite of split(), joins the elements in the given list together using the string                                                                        |

# %% [markdown]
# For example, to transform every character's name in the "character" column from lowercase to uppercase, we can use `.str.upper()`

# %%
film_df['character'].str.upper()
# Out:
# 0                  BETTY
# 1        CAROLYN JOHNSON
# 2                ELEANOR
# 3        FRANCESCA JOHNS
# 4                  MADGE
#               ...
# 23043            LUMIERE
# 23044            MAURICE
# 23045    MONSIEUR D'ARQU
# 23046         MRS. POTTS
# 23047           WARDROBE
# Name: character, Length: 23047, dtype: object

# %% [markdown]
# To transform every character's name in the "character" column to lowercase, we can use `.str.lower()`

# %%
film_df['character'].str.lower()
# Out:
# 0                  betty
# 1        carolyn johnson
# 2                eleanor
# 3        francesca johns
# 4                  madge
#               ...
# 23043            lumiere
# 23044            maurice
# 23045    monsieur d'arqu
# 23046         mrs. potts
# 23047           wardrobe
# Name: character, Length: 23047, dtype: object

# %% [markdown]
# We can use the `.str.contains()` to search for particular words or phrases in a column, such as "Star Wars."

# %%
film_df[film_df['title'].str.contains('Star Wars')]
# Out:
#              character  words gender   age  \
# 3017    Admiral Ackbar    199    Man  61.0
# 3018   Ben 'Obi-Wan' K    462    Man  69.0
# 3019             C-3Po    881    Man  37.0
# 3020       Darth Vader    381    Man  48.0
# 3021          Han Solo    835    Man  41.0
# 3022   Lando Calrissia    379    Man  46.0
# 3023    Luke Skywalker    915    Man  32.0
# 3024     Princess Leia    359  Woman  27.0
# 3025       The Emperor    516    Man  39.0
# 3026              Yoda    163    Man  19.0
# 3027   Anakin Skywalke   2061    Man  21.0
# 3028       Cliegg Lars    152    Man  62.0
# 3029       Count Dooku    321    Man  80.0
# 3030   Dexter Jettster    151    Man  67.0
# 3031     Jar Jar Binks    294    Man  29.0
# 3032           Lama Su    350    Man  48.0
# 3033        Mace Windu    365    Man  54.0
# 3034   Madame Jocasta     331  Woman  82.0
# 3035    Obi-Wan Kenobi   1477    Man  31.0
# 3036             Padme    668  Woman  21.0
# 3037    Queen Jamillia    135  Woman  25.0
# 3038   Supreme Chancel    576    Man  58.0
# 3039           Taun We    139  Woman  40.0
# 3040             Watto    140    Man  49.0
# 3041              Yoda    355    Man  58.0
# 3058   Ben Obi-Wan Ken    995    Man  63.0
# 3059             C-3Po   1506    Man  31.0
# 3060   Cmdr. Praji (Im    117    Man  42.0
# 3061       Darth Vader    492    Man  46.0
# 3062   General Dodonna    185    Man  66.0
# 3063   Grand Moff Tark    411    Man  64.0
# 3064            Greedo    103    Man  33.0
# 3065          Han Solo   1730    Man  35.0
# 3066             Jabba    185    Man   NaN
# 3067    Luke Skywalker   2485    Man  26.0
# 3068   Princess Leia O    636  Woman  21.0
# 3069        Red Leader    241    Man  37.0
# 3070   Red Three (Bigg    523    Man  38.0
# 3071      Stormtrooper    122    Man  36.0
# 3072        Uncle Owen    311    Man  61.0
# 10591  Anakin Skywalke   3768    Man  24.0
# 10592            C-3Po    312    Man  59.0
# 10593  Clone Jedi Knig    104    Man   NaN
# 10594    Darth Sldious    244    Man   NaN
# 10595  General Grievou    317    Man  33.0
# 10596  Ki-Adi-Mundi /     107    Man  40.0
# 10597       Mace Windu    407    Man  57.0
# 10598       Mon Mothma    127  Woman  28.0
# 10599   Obi-Wan Kenobi   3181    Man  34.0
# 10600            Padme   1561  Woman  24.0
# 10601  Senator Bail Or    479    Man  50.0
# 10602  Supreme Chancel   2367    Man  61.0
# 10603             Yoda    923    Man  61.0
# 10604    Admiral Piett    232    Man  43.0
# 10605  Ben (Obi-Wan) K    177    Man  66.0
# 10606            C-3Po   1474    Man  34.0
# 10607    Captain Needa    108    Man  42.0
# 10608      Darth Vader    853    Man  49.0
# 10609    General Veers    114    Man  45.0
# 10610         Han Solo   2024    Man  38.0
# 10611  Lando Calrissia    798    Man  43.0
# 10612   Luke Skywalker   1282    Man  29.0
# 10613    Princess Leia   1025  Woman  24.0
# 10614  Rebel Force Gen    168    Man  50.0
# 10615    Snow Creature    227    Man   NaN
# 10616             Yoda    751    Man  36.0
# 10617  Anakin Skywalke   1697    Man  10.0
# 10618        Boss Nass    209    Man  63.0
# 10619   Captain Panaka    390    Man  45.0
# 10620  Chancellor Valo    127    Man  61.0
# 10621    Darth Sidious    277    Man   NaN
# 10622    Jar Jar Binks    632    Man  26.0
# 10623       Mace Windu    247    Man  51.0
# 10624      Nute Gunray    544    Man  34.0
# 10625   Obi-Wan Kenobi    701    Man  28.0
# 10626            Padme    718  Woman  18.0
# 10627    Queen Amidala    656  Woman  18.0
# 10628     Qui-Gon Jinn   2339    Man  47.0
# 10629         Ric Oli�    132    Man  42.0
# 10630       Rune Haako    126    Man   NaN
# 10631  Senator Palpati    551    Man  55.0
# 10632   Shmi Skywalker    414  Woman  41.0
# 10633       Sio Bibble    164    Man  60.0
# 10634            Watto    502    Man  46.0
# 10635             Yoda    312    Man  55.0
# 21000         Bala-Tik    140    Man   NaN
# 21001            C-3Po    138    Man  69.0
# 21002             Finn   1447    Man  23.0
# 21003      General Hux    356    Man  32.0
# 21004         Han Solo   1225    Man  73.0
# 21005         Kylo Ren    618    Man  32.0
# 21006       Maz Kanata    241  Woman  32.0
# 21007      Poe Dameron    604    Man  36.0
# 21008    Princess Leia    252  Woman  59.0
# 21009              Rey   1363  Woman  23.0
# 21010     Stormtrooper    114    Man   NaN
# 21011  Supreme Leader     168    Man  51.0
#
#                                                 title  release_year   gross  \
# 3017       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3018       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3019       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3020       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3021       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3022       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3023       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3024       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3025       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3026       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3027     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3028     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3029     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3030     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3031     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3032     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3033     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3034     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3035     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3036     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3037     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3038     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3039     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3040     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3041     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3058               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3059               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3060               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3061               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3062               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3063               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3064               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3065               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3066               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3067               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3068               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3069               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3070               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3071               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3072               Star Wars: Episode IV - A New Hope          1977  1798.0
# 10591    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10592    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10593    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10594    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10595    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10596    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10597    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10598    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10599    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10600    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10601    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10602    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10603    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10604  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10605  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10606  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10607  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10608  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10609  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10610  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10611  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10612  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10613  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10614  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10615  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10616  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10617       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10618       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10619       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10620       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10621       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10622       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10623       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10624       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10625       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10626       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10627       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10628       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10629       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10630       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10631       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10632       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10633       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10634       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10635       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 21000      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21001      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21002      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21003      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21004      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21005      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21006      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21007      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21008      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21009      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21010      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21011      Star Wars: Episode VII - The Force Awakens          2015   927.0
#
#        proportion_of_dialogue  after_2000
# 3017                 0.039096       False
# 3018                 0.090766       False
# 3019                 0.173084       False
# 3020                 0.074853       False
# 3021                 0.164047       False
# 3022                 0.074460       False
# 3023                 0.179764       False
# 3024                 0.070530       False
# 3025                 0.101375       False
# 3026                 0.032024       False
# 3027                 0.274251        True
# 3028                 0.020226        True
# 3029                 0.042715        True
# 3030                 0.020093        True
# 3031                 0.039122        True
# 3032                 0.046574        True
# 3033                 0.048570        True
# 3034                 0.044045        True
# 3035                 0.196540        True
# 3036                 0.088889        True
# 3037                 0.017964        True
# 3038                 0.076647        True
# 3039                 0.018496        True
# 3040                 0.018629        True
# 3041                 0.047239        True
# 3058                 0.099084       False
# 3059                 0.149970       False
# 3060                 0.011651       False
# 3061                 0.048994       False
# 3062                 0.018423       False
# 3063                 0.040928       False
# 3064                 0.010257       False
# 3065                 0.172276       False
# 3066                 0.018423       False
# 3067                 0.247461       False
# 3068                 0.063334       False
# 3069                 0.023999       False
# 3070                 0.052081       False
# 3071                 0.012149       False
# 3072                 0.030970       False
# 10591                0.271138        True
# 10592                0.022451        True
# 10593                0.007484        True
# 10594                0.017558        True
# 10595                0.022811        True
# 10596                0.007700        True
# 10597                0.029287        True
# 10598                0.009139        True
# 10599                0.228898        True
# 10600                0.112326        True
# 10601                0.034468        True
# 10602                0.170325        True
# 10603                0.066417        True
# 10604                0.025127       False
# 10605                0.019170       False
# 10606                0.159645       False
# 10607                0.011697       False
# 10608                0.092386       False
# 10609                0.012347       False
# 10610                0.219214       False
# 10611                0.086429       False
# 10612                0.138850       False
# 10613                0.111015       False
# 10614                0.018196       False
# 10615                0.024586       False
# 10616                0.081339       False
# 10617                0.158037       False
# 10618                0.019464       False
# 10619                0.036320       False
# 10620                0.011827       False
# 10621                0.025796       False
# 10622                0.058856       False
# 10623                0.023002       False
# 10624                0.050661       False
# 10625                0.065282       False
# 10626                0.066865       False
# 10627                0.061091       False
# 10628                0.217825       False
# 10629                0.012293       False
# 10630                0.011734       False
# 10631                0.051313       False
# 10632                0.038555       False
# 10633                0.015273       False
# 10634                0.046750       False
# 10635                0.029056       False
# 21000                0.021002        True
# 21001                0.020702        True
# 21002                0.217072        True
# 21003                0.053405        True
# 21004                0.183768        True
# 21005                0.092709        True
# 21006                0.036154        True
# 21007                0.090609        True
# 21008                0.037804        True
# 21009                0.204470        True
# 21010                0.017102        True
# 21011                0.025203        True

# %% [markdown]
# We can use the `.str.contains()` to search for particular words or phrases in a column, such as "Mean Girls."

# %%
film_df[film_df['title'].str.contains('Mean Girls')]
# Out:
#              character  words gender   age       title  release_year  gross  \
# 13938    Aaron Samuels    426    Man  23.0  Mean Girls          2004  120.0
# 13939       Cady Heron   2798  Woman  18.0  Mean Girls          2004  120.0
# 13940           Damian    624    Man  26.0  Mean Girls          2004  120.0
# 13941  Gretchen Wiener    609  Woman  22.0  Mean Girls          2004  120.0
# 13942        Janis Ian    907  Woman  22.0  Mean Girls          2004  120.0
# 13943      Karen Smith    301  Woman  19.0  Mean Girls          2004  120.0
# 13944       Mr. Duvall    365    Man  43.0  Mean Girls          2004  120.0
# 13945      Mrs. George    125  Woman  33.0  Mean Girls          2004  120.0
# 13946      Ms. Norbury    720  Woman  34.0  Mean Girls          2004  120.0
# 13947    Regina George   1030  Woman  26.0  Mean Girls          2004  120.0
#
#        proportion_of_dialogue  after_2000
# 13938                0.053890        True
# 13939                0.353953        True
# 13940                0.078937        True
# 13941                0.077040        True
# 13942                0.114738        True
# 13943                0.038077        True
# 13944                0.046173        True
# 13945                0.015813        True
# 13946                0.091082        True
# 13947                0.130297        True

# %% [markdown]
# ## Applying Functions

# %% [markdown]
# With the `.apply()` method, we can run a function on every single row in a Pandas column or dataframe.

# %%
def make_text_title_case(text):
    title_case_text = text.title()
    return title_case_text

# %%
make_text_title_case("betty")
# Out:
# 'Betty'

# %%
film_df['character'].apply(make_text_title_case)
# Out:
# 0                  Betty
# 1        Carolyn Johnson
# 2                Eleanor
# 3        Francesca Johns
# 4                  Madge
#               ...
# 23043            Lumiere
# 23044            Maurice
# 23045    Monsieur D'Arqu
# 23046         Mrs. Potts
# 23047           Wardrobe
# Name: character, Length: 23047, dtype: object

# %%
film_df['character'] = film_df['character'].apply(make_text_title_case)

# %%
film_df.sample(10)
# Out:
#           character  words gender   age                            title  \
# 18717           Deb    114  Woman   NaN  I Know What You Did Last Summer
# 15491  Reese Wilson    322  Woman  49.0                     Urban Legend
# 4011       Reporter    156    Man  35.0           The American President
# 449         Salgado    103    Man  51.0                      Being Human
# 15114          Worf    363    Man  42.0           Star Trek: Generations
# 22361   Bruce Wayne   1978    Man  38.0            The Dark Knight Rises
# 17924   Officer Don    157    Man  51.0             Career Opportunities
# 8697      Bob Zmuda   1062    Man  32.0                  Man on the Moon
# 10472    Bill Pardy   2656    Man  35.0                          Slither
# 4159        Henry V    279    Man   NaN                        Anonymous
#
#        release_year  gross  proportion_of_dialogue  after_2000
# 18717          1997  136.0                0.020152       False
# 15491          1998   70.0                0.043042       False
# 4011           1995  130.0                0.004431       False
# 449            1994    3.0                0.008315       False
# 15114          1994  157.0                0.039603       False
# 22361          2012  489.0                0.193561        True
# 17924          1991   23.0                0.014636       False
# 8697           1999   59.0                0.062295       False
# 10472          2006   10.0                0.292511        True
# 4159           2011    4.0                0.024973        True

# %% [markdown]
# ### Filter DataFrame

# %% [markdown]
# We can filter the DataFrames for only characters who are men or women.

# %%
men_film_df = film_df[film_df['gender'] == 'Man']
men_film_df.head()
# Out:
#           character  words gender   age                          title  \
# 5   Michael Johnson    723    Man  38.0  The Bridges of Madison County
# 6    Robert Kincaid   1908    Man  65.0  The Bridges of Madison County
# 7      Bobby Korfin    328    Man   NaN                     15 Minutes
# 9   Deputy Chief Fi    347    Man   NaN                     15 Minutes
# 10  Detective Eddie   2020    Man  58.0                     15 Minutes
#
#     release_year  gross  proportion_of_dialogue  after_2000
# 5           1995  142.0                0.113075       False
# 6           1995  142.0                0.298405       False
# 7           2001   37.0                0.036012        True
# 9           2001   37.0                0.038098        True
# 10          2001   37.0                0.221783        True

# %%
women_film_df = film_df[film_df['gender'] == 'Woman']
women_film_df.head()
# Out:
#          character  words gender   age                          title  \
# 0            Betty    311  Woman  35.0  The Bridges of Madison County
# 1  Carolyn Johnson    873  Woman   NaN  The Bridges of Madison County
# 2          Eleanor    138  Woman   NaN  The Bridges of Madison County
# 3  Francesca Johns   2251  Woman  46.0  The Bridges of Madison County
# 4            Madge    190  Woman  46.0  The Bridges of Madison County
#
#    release_year  gross  proportion_of_dialogue  after_2000
# 0          1995  142.0                0.048639       False
# 1          1995  142.0                0.136534       False
# 2          1995  142.0                0.021583       False
# 3          1995  142.0                0.352049       False
# 4          1995  142.0                0.029715       False

# %% [markdown]
# ### Groupby

# %% [markdown]
# We can use the `.groupby()` function to group all the men characters in each film and sum up their total dialogue.

# %% [markdown]
# By adding a Python string slice, we can identify the top 20 films with the greatest proportion of men speaking.

# %% [markdown]
# Line Breaks:
# If a line of code gets too long, you can create a line break with a backslash `\`

# %%
men_film_df.groupby('title')[['proportion_of_dialogue']]\
.sum().sort_values(by='proportion_of_dialogue', ascending=False)[:20]
# Out:
#                                     proportion_of_dialogue
# title
# The Men Who Stare at Goats                             1.0
# Kagemusha                                              1.0
# The Wild Bunch                                         1.0
# Killing Them Softly                                    1.0
# Stalag 17                                              1.0
# There Will Be Blood                                    1.0
# Fury                                                   1.0
# The Revenant                                           1.0
# Saving Private Ryan                                    1.0
# Crimson Tide                                           1.0
# Die Hard: With a Vengeance                             1.0
# Jeremiah Johnson                                       1.0
# Conquest of the Planet of the Apes                     1.0
# Duel                                                   1.0
# The Hunt for Red October                               1.0
# Platoon                                                1.0
# Reservoir Dogs                                         1.0
# The Battle of Algiers                                  1.0
# Armored                                                1.0
# Space Jam                                              1.0

# %% [markdown]
# We can use the `.groupby()` function to group all the women characters in each film and sum up their total dialogue.

# %% [markdown]
# By adding a Python string slice, we can identify the top 20 films with the greatest proportion of women speaking.

# %%
women_film_df.groupby('title')[['proportion_of_dialogue']]\
.sum().sort_values(by='proportion_of_dialogue', ascending=False)[:20]
# Out:
#                                 proportion_of_dialogue
# title
# The Descent                                   1.000000
# Now and Then                                  1.000000
# Precious                                      0.993541
# Martyrs                                       0.965550
# The Hand That Rocks the Cradle                0.933750
# Agnes of God                                  0.922482
# Heavenly Creatures                            0.919368
# The Help                                      0.916947
# 3 Women                                       0.899530
# The Watermelon Woman                          0.894676
# Grandma                                       0.894137
# The Craft                                     0.891866
# Easy A                                        0.888131
# The Others                                    0.879972
# Black Christmas                               0.877467
# Wadjda                                        0.870567
# For Colored Girls                             0.870247
# The Roommate                                  0.869879
# Mrs. Winterbourne                             0.864730
# Practical Magic                               0.856693

# %% [markdown]
# ## Reset Index

# %% [markdown]
# We can transform a Groupby object into a DataFrame with a regular Index by tacking on `.reset_index()`.

# %%
women_film_df.groupby('title')[['proportion_of_dialogue']]\
.sum().sort_values(by='proportion_of_dialogue', ascending=False).reset_index()
# Out:
#                                title  proportion_of_dialogue
# 0                        The Descent                1.000000
# 1                       Now and Then                1.000000
# 2                           Precious                0.993541
# 3                            Martyrs                0.965550
# 4     The Hand That Rocks the Cradle                0.933750
# ...                              ...                     ...
# 1935                 The Last Castle                0.011139
# 1936               The Damned United                0.010909
# 1937                   Thirteen Days                0.010834
# 1938                  Men in Black 3                0.007812
# 1939               Full Metal Jacket                0.007170
#
# [1940 rows x 2 columns]

# %% [markdown]
# ## Your turn!

# %% [markdown]
# Go back through this notebook, changing the code to explore the film corpus as you see fit.
